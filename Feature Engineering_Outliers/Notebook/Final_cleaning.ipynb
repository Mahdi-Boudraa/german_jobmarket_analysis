# %%
import pandas as pd
import json

# %%
df = pd.read_csv("jobs_with_requirements.csv")
df = df.drop(df.columns[0], axis=1)

# %%
#change the type to dictionary to make manipulation easier
df["requirements_extracted"] = df.requirements_extracted.apply(eval)

# %%
df["hard_skills"] = df.requirements_extracted.apply(lambda x : x.get("hard_skills"))

# %%
df["languages"] = df.requirements_extracted.apply(lambda x: x.get("languages"))

# %%
df.requirements_extracted[2]
# Out:
# {'hard_skills': {'programming language': 'other',
#   'data science': 'data science & ai'},
#  'languages': ['german'],
#  'experience': None,
#  'education': {'degree': 'degree', 'computer science': 'field'},
#  'soft_skills': ['analytical', 'communication', 'initiative']}

# %%
df["experience"] = df.requirements_extracted.apply(lambda x: x.get("experience"))

# %%
df["degree"] = df.requirements_extracted.apply(lambda x : x.get("education"))

# %%
df["soft_skills"] = df.requirements_extracted.apply(lambda x: x.get("soft_skills"))

# %%
df = df.drop(columns= ["requirements_extracted"],axis =1)

# %%
df["skills"] = df.hard_skills.apply(lambda x : list(x.keys()))

# %%
df[df["skills"].apply(lambda x : len(x)) == 0]
# Out:
#                                                   title  \
# 27        - Data Science Artificial Intelligence Autumn
# 29               - Data Science Artificial Intelligence
# 34    Full-Stack Data Analytics Data Science Expert ...
# 40    Mathematician Actuar Data Science Pricing Risk...
# 54                                       Data Scientist
# ...                                                 ...
# 3016           Planning Coordinator - Area Data Centers
# 3017     System Engineer It - Firewall Network Security
# 3018                       Information Security Advisor
# 3021                                    Cloud Architekt
# 3024                             It Security Consultant
#
#                                                 company  \
# 27                                                ZEISS
# 29                  Schaeffler Technologies AG & Co. KG
# 34                                     Mercedes-Benz AG
# 40    Meyerthole Siems Kohlruss Ges. für aktuarielle...
# 54                                          monari GmbH
# ...                                                 ...
# 3016                                      Ed. Züblin AG
# 3017                              Landkreis Emmendingen
# 3018                                        neoshare AG
# 3021                                                ZDF
# 3024       FERCHAU – Connecting People and Technologies
#
#                                   location  \
# 27          Oberkochen (Baden-Württemberg)
# 29                          Herzogenaurach
# 34                               Stuttgart
# 40                                    Köln
# 54                                  Gronau
# ...                                    ...
# 3016  Frankfurt am Main, Rhein-Main-Gebiet
# 3017                           Emmendingen
# 3018              München, Frankfurt a. M.
# 3021                                 Mainz
# 3024                                Bremen
#
#                                       job_type  \
# 27                         Ausbildung, Studium
# 29                         Ausbildung, Studium
# 34                            Feste Anstellung
# 40    Berufseinstieg/Trainee, Feste Anstellung
# 54                            Feste Anstellung
# ...                                        ...
# 3016                          Feste Anstellung
# 3017                          Feste Anstellung
# 3018                          Feste Anstellung
# 3021                          Feste Anstellung
# 3024                          Feste Anstellung
#
#                              employment_type  \
# 27                                  Vollzeit
# 29                                  Vollzeit
# 34    Homeoffice möglich, Teilzeit, Vollzeit
# 40                                  Vollzeit
# 54              Homeoffice möglich, Vollzeit
# ...                                      ...
# 3016                                Vollzeit
# 3017            Homeoffice möglich, Vollzeit
# 3018            Homeoffice möglich, Vollzeit
# 3021                      Teilzeit, Vollzeit
# 3024                                Vollzeit
#
#                                             description  \
# 27    Be the change i be sgshißen for curious, passi...
# 29    We are the Federal Agency for Cartography and ...
# 34    Diedrescher Consulting GmbHist ANDER -RIGHTIC ...
# 40    Are you an analyst, designer and do you want t...
# 54    Our passion for technical challenges drives us...
# ...                                                 ...
# 3016  As part of Strabag SE and number one in German...
# 3017  Your attractive employer in the region for str...
# 3018  NEOSHARE AG, founded in Munich in 2019, quickl...
# 3021  The Planning and Realization business area (PU...
# 3024  Do you know that security comes first in today...
#
#                                            requirements  \
# 27    You have completed studies with technical-scie...
# 29    Study course in the field of industrial engine...
# 34    Several years of experience as a project manag...
# 40    PhD in life or data sciences and/or MD in medi...
# 54    General university entrance qualifications, su...
# ...                                                 ...
# 3016  You have a degree in business administration, ...
# 3017  You have completed technical training or a deg...
# 3018  General/subject-bound high school graduation s...
# 3021  You have a completed training as a bank clerk ...
# 3024  You bring a good conclusion as a bachelor's ch...
#
#                              job_category hard_skills          languages  \
# 27              IT|Data & AI|Data Science          {}               None
# 29              IT|Data & AI|Data Science          {}  [german, english]
# 34              IT|Data & AI|Data Science          {}  [german, english]
# 40              IT|Data & AI|Data Science          {}               None
# 54              IT|Data & AI|Data Science          {}          [english]
# ...                                   ...         ...                ...
# 3016           IT|Data & AI|Data Analysis          {}  [german, english]
# 3017     Engineering|Industrial & Systems          {}  [german, english]
# 3018                 Legal|Legal Practice          {}               None
# 3021  IT|DevOps & Cloud|Cloud Engineering          {}               None
# 3024        Legal|Compliance & Regulatory          {}               None
#
#      experience                                             degree  \
# 27         None                                               None
# 29         None  {'degree': 'degree', 'economic': 'field', 'eng...
# 34         None                                               None
# 40      3 years                                               None
# 54         None                                               None
# ...         ...                                                ...
# 3016       None  {'degree': 'degree', 'engineering': 'field', '...
# 3017       None  {'degree': 'degree', 'engineering': 'field', '...
# 3018       None                                               None
# 3021       None                                               None
# 3024       None                                               None
#
#                       soft_skills skills
# 27    [management, communication]     []
# 29                           None     []
# 34                [communication]     []
# 40    [collaboration, initiative]     []
# 54    [communication, initiative]     []
# ...                           ...    ...
# 3016     [analytical, management]     []
# 3017                         None     []
# 3018                         None     []
# 3021              [communication]     []
# 3024                 [analytical]     []
#
# [1423 rows x 14 columns]

# %% [markdown]
# ## too many rows without skills we need to fix this

# %%
SKILL_CATEGORIES = {
    # --- Programming Languages ---
    'Programming Languages': [
        'python', 'java', 'javascript', 'typescript', 'c++', 'c#', 'go', 'golang',
        'ruby', 'php', 'swift', 'kotlin', 'rust', 'scala', 'r', 'dart', 'perl',
        'bash', 'html', 'css', 'Python', 'oop', 'object-oriented','object-oriented programming'
    ],

    # --- Web Development ---
    'Web Development': [
        'react', 'angular', 'vue', 'svelte', 'next.js', 'nuxt.js', 'jquery','full-stack'
        'd3.js', 'redux', 'webpack', 'babel', 'tailwind', 'bootstrap', 'sass','full stack'
        'less', 'graphql', 'rest', 'api','web development', 'web dev','web developer'
    ],

    # --- Backend Development ---
    'Backend Development': [
        'node.js', 'express', 'django', 'flask', 'spring', 'spring boot',
        'laravel', 'ruby on rails', 'asp.net', '.net core', 'fastapi', 'nestjs', 'full stack',
        'hibernate', 'jpa', 'gin', 'echo','api', 'rest','rest api', 'restful','full-stack'
    ],

    # --- Mobile & Game Development ---
    'Mobile & Game Dev': [
        'react native', 'flutter', 'xamarin', 'ionic', 'unity', 'unreal engine',
        'cocos2d', 'godot', 'opengl', 'directx', 'phaser', 'pixi.js'
    ],

    # --- Cloud & DevOps ---
    'Cloud & DevOps': [
        'aws', 'azure', 'google cloud', 'gcp', 'docker', 'kubernetes',
        'terraform', 'ansible', 'jenkins', 'github actions', 'gitlab ci',
        'circleci', 'argo cd', 'helm', 'prometheus', 'grafana', 'splunk',
        'new relic', 'datadog', 'istio', 'linkerd', 'cloud','cloud computing'
    ],

    # --- Databases ---
    'Databases': [
        'sql', 'postgresql', 'mysql', 'mongodb', 'redis', 'cassandra', 'databases',
        'elasticsearch', 'dynamodb', 'firebase', 'snowflake', 'bigquery','relational',
        'oracle', 'sql server', 'mariadb', 'neo4j', 'cosmos db', 'database','non relational'
        'no sql','nosql','non-relational'
    ],

    # --- Data Science & AI ---
    'Data Science & AI': [
        'pandas', 'numpy', 'scikit-learn', 'tensorflow', 'pytorch', 'keras',
        'opencv', 'spark', 'hadoop', 'hive', 'kafka', 'airflow', 'mlflow',
        'ray', 'nltk', 'spacy', 'hugging face', 'langchain', 'llama', 'gpt',
        'bert', 'transformers', 'computer vision', 'nlp', 'ai', 'Artificial Intelligence',
        'reinforcement learning', 'supervised learning', 'unsupervised learning',
        'ai management', 'ai developement', 'llm', 'deep learning', 'tensorflow',
        'pytorch','data science','data scientist', 'ai engineer', 'ai engineering'
    ],

    # --- Data Engineering ---
    'Data Engineering': [
        'etl', 'elt', 'data pipeline', 'data warehouse', 'data lake',
        'delta lake', 'apache beam', 'apache flink', 'dbt', 'prefect',
        'dagster', 'redshift', 'databricks', 'data strategy', 'data architecture',
        'data foundation', 'data management', 'data engineering', 'data engineer'
    ],

    # --- BI & Analytics ---
    'BI & Analytics': [
        'tableau', 'power bi', 'looker', 'qlikview', 'qliksense', 'bi tools','bi'
        'microstrategy', 'sisense', 'domo', 'matplotlib', 'seaborn', 'dashboards',
        'plotly', 'ggplot', 'excel', 'google sheets', 'vba', 'pbi','dashboard',
        'business intelligence','visualization', 'data analysis','data visualization'
    ],

    # --- Cybersecurity ---
    'Cybersecurity': [
        'owasp', 'penetration testing', 'metasploit', 'burp suite',
        'wireshark', 'nmap', 'siem', 'soc', 'ids', 'ips', 'firewall',
        'vpn', 'zero trust', 'saml', 'oauth', 'openid', 'iso 27001',
        'gdpr', 'hipaa', 'pci dss', 'nist', 'cis controls','security'
    ],

    # --- QA & Testing ---
    'QA & Testing': [
        'selenium', 'cypress', 'jest', 'mocha', 'junit', 'testng',
        'pytest', 'postman', 'soapui', 'jmeter', 'loadrunner',
        'appium', 'cucumber', 'specflow', 'robot framework'
    ],

    # --- Business Systems ---
    'Business Systems': [
        'sap', 'salesforce', 'microsoft dynamics', 'oracle erp',
        'netsuite', 'workday', 'peoplesoft', 'sage', 'odoo', 'zoho',
        'hubspot', 'microsoft power platform', 'sharepoint'
    ],

    # --- IT & Administration ---
    'IT & Admin': [
        'active directory', 'windows server', 'linux', 'ubuntu',
        'centos', 'red hat', 'macos', 'vmware', 'hyper-v', 'citrix',
        'azure ad', 'office 365', 'exchange', 'powershell'
    ],

    # --- Business & Management ---
    'Business & Management': [
        'control models', 'business relationships', 'financial modeling',
        'risk management', 'strategic planning', 'project management'
    ],

    # --- Design & Creative ---
    'Design & Creative': [
        'figma', 'adobe xd', 'sketch', 'illustrator', 'photoshop',
        'indesign', 'after effects', 'premiere pro', 'maya', 'blender',
        'autocad', 'solidworks', 'revit', '3d modeling'
    ],

    # --- Industry-Specific ---
    'Healthcare IT': [
        'hl7', 'fhir', 'epic', 'cerner', 'meditech', 'hipaa compliance',
        'electronic health records'
    ],
    'Manufacturing': [
        'plc', 'scada', 'cnc', 'cad/cam', 'industry 4.0', 'iot',
        'lean manufacturing', 'six sigma'
    ],
    'Logistics': [
        'wms', 'tms', 'supply chain', 'inventory management',
        'sap mm', 'sap sd', 'sap ewm'
    ],
    'Marketing Tech': [
        'seo', 'sem', 'ppc', 'google analytics', 'google tag manager',
        'facebook ads', 'linkedin ads', 'marketing automation',
        'content marketing', 'social media marketing', 'email marketing'
    ],
    'Office Tools': [
        'word', 'ms office', 'outlook', 'ms office suite', 'powerpoint',
        'excel', 'google docs', 'google sheets'
    ]
}

# Flatten all keywords into a single set (for faster matching)
all_skills = set()
for category in SKILL_CATEGORIES.values():
    all_skills.update([skill.lower() for skill in category])

# Optionally: Add variations (e.g., "C++" -> "c++", "cplusplus")
all_skills.add("cplusplus")  # Example additional variation

import re

def extract_skills_simple(text):
    if not isinstance(text, str):
        return []
    
    text_lower = text.lower()
    found_skills = []
    
    for skill in all_skills:
        # Match whole words only (to avoid partial matches)
        if re.search(rf'\b{re.escape(skill)}\b', text_lower):
            found_skills.append(skill)
    
    return list(set(found_skills))  # Remove duplicates

# %%
mask = df.skills.apply(lambda x : len(x)) == 0
df.loc[mask , "skills"] = df[mask].requirements.apply(extract_skills_simple)

# %%
df[df["skills"].apply(lambda x : len(x)) == 0]
# Out:
#                                           title  \
# 58           Consultant Artificial Intelligence
# 74           Artificial Intelligence Specialist
# 75                                          NaN
# 96                                          NaN
# 106             Business Development Cpo Office
# ...                                         ...
# 3007                                        NaN
# 3008  Employee It Development Leadership Skills
# 3009            Employee It Development Support
# 3018               Information Security Advisor
# 3024                     It Security Consultant
#
#                                            company  \
# 58                                       adesso SE
# 74           SGS Holding Deutschland B.V. & Co. KG
# 75                                             NaN
# 96                                             NaN
# 106                    DFMG Deutsche Funkturm GmbH
# ...                                            ...
# 3007                                           NaN
# 3008                      Regierung von Oberbayern
# 3009                      Regierung von Oberbayern
# 3018                                   neoshare AG
# 3024  FERCHAU – Connecting People and Technologies
#
#                                                location  \
# 58    Aachen, Bonn, Dortmund, Düsseldorf, Essen, Fra...
# 74                                              Hamburg
# 75                                                  NaN
# 96                                                  NaN
# 106                                          Leverkusen
# ...                                                 ...
# 3007                                                NaN
# 3008                     München, Rosenheim, Ingolstadt
# 3009                     München, Rosenheim, Ingolstadt
# 3018                           München, Frankfurt a. M.
# 3024                                             Bremen
#
#                         job_type                         employment_type  \
# 58              Feste Anstellung            Homeoffice möglich, Vollzeit
# 74              Feste Anstellung            Homeoffice möglich, Vollzeit
# 75                           NaN                                     NaN
# 96                           NaN                                     NaN
# 106   Studentenjobs, Werkstudent            Homeoffice möglich, Teilzeit
# ...                          ...                                     ...
# 3007                         NaN                                     NaN
# 3008            Feste Anstellung  Homeoffice möglich, Teilzeit, Vollzeit
# 3009            Feste Anstellung  Homeoffice möglich, Teilzeit, Vollzeit
# 3018            Feste Anstellung            Homeoffice möglich, Vollzeit
# 3024            Feste Anstellung                                Vollzeit
#
#                                             description  \
# 58    With this guideline, we have been setting regi...
# 74    Life is Alway's About Becoming ... In life it ...
# 75                                                  NaN
# 96                                                  NaN
# 106   VR Smart Finanz AG belongs to the DZ Bank Grou...
# ...                                                 ...
# 3007                                                NaN
# 3008  We are a modern, powerful and future -oriented...
# 3009  We are a modern, powerful and future -oriented...
# 3018  NEOSHARE AG, founded in Munich in 2019, quickl...
# 3024  Do you know that security comes first in today...
#
#                                            requirements  \
# 58    (Specialist) Abitur with good grades-especiall...
# 74    You have (soon) your Abitur and want to start ...
# 75                                                  NaN
# 96                                                  NaN
# 106   PhD in life or data sciences and/or MD in medi...
# ...                                                 ...
# 3007                                                NaN
# 3008  This should be the right thing for you to trai...
# 3009  This should be the right thing for you to trai...
# 3018  General/subject-bound high school graduation s...
# 3024  You bring a good conclusion as a bachelor's ch...
#
#                                          job_category hard_skills  \
# 58                         IT|Data & AI|AI, LLM & NLP          {}
# 74                         IT|Data & AI|AI, LLM & NLP          {}
# 75                                                NaN          {}
# 96                                                NaN          {}
# 106                  Business|Sales & Marketing|Sales          {}
# ...                                               ...         ...
# 3007                                              NaN          {}
# 3008  Public Sector & Non-Profit|Education & Research          {}
# 3009                 IT|IT Support|Helpdesk & Support          {}
# 3018                             Legal|Legal Practice          {}
# 3024                    Legal|Compliance & Regulatory          {}
#
#               languages experience  \
# 58    [german, english]       None
# 74             [german]       None
# 75                 None       None
# 96                 None       None
# 106                None    3 years
# ...                 ...        ...
# 3007               None       None
# 3008               None       None
# 3009               None       None
# 3018               None       None
# 3024               None       None
#
#                                                  degree  \
# 58                                                 None
# 74    {'bachelor's': 'degree', 'degree': 'degree', '...
# 75                                                 None
# 96                                                 None
# 106                                                None
# ...                                                 ...
# 3007                                               None
# 3008                                               None
# 3009                                               None
# 3018                                               None
# 3024                                               None
#
#                                   soft_skills skills
# 58                                       None     []
# 74    [analytical, communication, initiative]     []
# 75                                       None     []
# 96                                       None     []
# 106                              [leadership]     []
# ...                                       ...    ...
# 3007                                     None     []
# 3008                             [management]     []
# 3009                                     None     []
# 3018                                     None     []
# 3024                             [analytical]     []
#
# [887 rows x 14 columns]

# %%
mask = df.skills.apply(lambda x : len(x)) == 0
df.loc[mask , "skills"] = df[mask].title.apply(extract_skills_simple)

# %%
df[df["skills"].apply(lambda x : len(x)) == 0]
# Out:
#                                                   title  \
# 75                                                  NaN
# 96                                                  NaN
# 106                     Business Development Cpo Office
# 113          Industrial Engineer Digital Transformation
# 131                                                 NaN
# ...                                                 ...
# 2995                                                NaN
# 3005  Engineer City Planner Landscape Architect Obje...
# 3007                                                NaN
# 3008          Employee It Development Leadership Skills
# 3009                    Employee It Development Support
#
#                           company                        location  \
# 75                            NaN                             NaN
# 96                            NaN                             NaN
# 106   DFMG Deutsche Funkturm GmbH                      Leverkusen
# 113                     WTSH GmbH                            Kiel
# 131                           NaN                             NaN
# ...                           ...                             ...
# 2995                          NaN                             NaN
# 3005                 Stadt Hameln                          Hameln
# 3007                          NaN                             NaN
# 3008     Regierung von Oberbayern  München, Rosenheim, Ingolstadt
# 3009     Regierung von Oberbayern  München, Rosenheim, Ingolstadt
#
#                         job_type                         employment_type  \
# 75                           NaN                                     NaN
# 96                           NaN                                     NaN
# 106   Studentenjobs, Werkstudent            Homeoffice möglich, Teilzeit
# 113          Befristeter Vertrag            Homeoffice möglich, Vollzeit
# 131                          NaN                                     NaN
# ...                          ...                                     ...
# 2995                         NaN                                     NaN
# 3005            Feste Anstellung  Homeoffice möglich, Teilzeit, Vollzeit
# 3007                         NaN                                     NaN
# 3008            Feste Anstellung  Homeoffice möglich, Teilzeit, Vollzeit
# 3009            Feste Anstellung  Homeoffice möglich, Teilzeit, Vollzeit
#
#                                             description  \
# 75                                                  NaN
# 96                                                  NaN
# 106   VR Smart Finanz AG belongs to the DZ Bank Grou...
# 113   With us you have an impact on the development ...
# 131                                                 NaN
# ...                                                 ...
# 2995                                                NaN
# 3005  This is what the city of Hameln, also known as...
# 3007                                                NaN
# 3008  We are a modern, powerful and future -oriented...
# 3009  We are a modern, powerful and future -oriented...
#
#                                            requirements  \
# 75                                                  NaN
# 96                                                  NaN
# 106   PhD in life or data sciences and/or MD in medi...
# 113   You have a completed degree in (economic) comp...
# 131                                                 NaN
# ...                                                 ...
# 2995                                                NaN
# 3005  This position requires fluent German language ...
# 3007                                                NaN
# 3008  This should be the right thing for you to trai...
# 3009  This should be the right thing for you to trai...
#
#                                          job_category hard_skills  \
# 75                                                NaN          {}
# 96                                                NaN          {}
# 106                  Business|Sales & Marketing|Sales          {}
# 113                  Engineering|Industrial & Systems          {}
# 131                                               NaN          {}
# ...                                               ...         ...
# 2995                                              NaN          {}
# 3005         IT|IT Management|Enterprise Architecture          {}
# 3007                                              NaN          {}
# 3008  Public Sector & Non-Profit|Education & Research          {}
# 3009                 IT|IT Support|Helpdesk & Support          {}
#
#               languages  experience  \
# 75                 None        None
# 96                 None        None
# 106                None     3 years
# 113   [german, english]  5 years of
# 131                None        None
# ...                 ...         ...
# 2995               None        None
# 3005           [german]  5 years of
# 3007               None        None
# 3008               None        None
# 3009               None        None
#
#                                                  degree  \
# 75                                                 None
# 96                                                 None
# 106                                                None
# 113   {'degree': 'degree', 'economic': 'field', 'eng...
# 131                                                None
# ...                                                 ...
# 2995                                               None
# 3005                                               None
# 3007                                               None
# 3008                                               None
# 3009                                               None
#
#                                      soft_skills skills
# 75                                          None     []
# 96                                          None     []
# 106                                 [leadership]     []
# 113                              [communication]     []
# 131                                         None     []
# ...                                          ...    ...
# 2995                                        None     []
# 3005  [management, collaboration, communication]     []
# 3007                                        None     []
# 3008                                [management]     []
# 3009                                        None     []
#
# [843 rows x 14 columns]

# %%
df = df.dropna(subset=["title"])

# %%
df[df["skills"].apply(lambda x : len(x)) == 0]
# Out:
#                                                   title  \
# 106                     Business Development Cpo Office
# 113          Industrial Engineer Digital Transformation
# 133           Software Developer Genai Machine Learning
# 138   Computer Science Software Technology Training ...
# 141   Training Computer Science Network Technology S...
# ...                                                 ...
# 2991              Merchant Forwarding Logistics Service
# 2992                     Specialist Warehouse Logistics
# 3005  Engineer City Planner Landscape Architect Obje...
# 3008          Employee It Development Leadership Skills
# 3009                    Employee It Development Support
#
#                           company                        location  \
# 106   DFMG Deutsche Funkturm GmbH                      Leverkusen
# 113                     WTSH GmbH                            Kiel
# 133                  REWE digital                            Köln
# 138    GEA Farm Technologies GmbH                           Bönen
# 141    GEA Farm Technologies GmbH                           Bönen
# ...                           ...                             ...
# 2991          Kiessling Spedition                      Regenstauf
# 2992          Kiessling Spedition                      Regenstauf
# 3005                 Stadt Hameln                          Hameln
# 3008     Regierung von Oberbayern  München, Rosenheim, Ingolstadt
# 3009     Regierung von Oberbayern  München, Rosenheim, Ingolstadt
#
#                         job_type                         employment_type  \
# 106   Studentenjobs, Werkstudent            Homeoffice möglich, Teilzeit
# 113          Befristeter Vertrag            Homeoffice möglich, Vollzeit
# 133             Feste Anstellung  Homeoffice möglich, Teilzeit, Vollzeit
# 138          Ausbildung, Studium                                Vollzeit
# 141          Ausbildung, Studium                                Vollzeit
# ...                          ...                                     ...
# 2991         Ausbildung, Studium                                Teilzeit
# 2992         Ausbildung, Studium                                Teilzeit
# 3005            Feste Anstellung  Homeoffice möglich, Teilzeit, Vollzeit
# 3008            Feste Anstellung  Homeoffice möglich, Teilzeit, Vollzeit
# 3009            Feste Anstellung  Homeoffice möglich, Teilzeit, Vollzeit
#
#                                             description  \
# 106   VR Smart Finanz AG belongs to the DZ Bank Grou...
# 113   With us you have an impact on the development ...
# 133   TÜV Süd has stood for security, quality and su...
# 138   Why are you exactly right with us? Because we ...
# 141   As a worldwide company, we need an IT landscap...
# ...                                                 ...
# 2991  The professional design of logistical processe...
# 2992  The professional design of logistical processe...
# 3005  This is what the city of Hameln, also known as...
# 3008  We are a modern, powerful and future -oriented...
# 3009  We are a modern, powerful and future -oriented...
#
#                                            requirements  \
# 106   PhD in life or data sciences and/or MD in medi...
# 113   You have a completed degree in (economic) comp...
# 133                                                 NaN
# 138   General university entrance qualifications wit...
# 141   General university entrance qualifications wit...
# ...                                                 ...
# 2991  • A preference for technical challenges- also ...
# 2992  RequirementsAt Code17, we value passion, creat...
# 3005  This position requires fluent German language ...
# 3008  This should be the right thing for you to trai...
# 3009  This should be the right thing for you to trai...
#
#                                          job_category hard_skills  \
# 106                  Business|Sales & Marketing|Sales          {}
# 113                  Engineering|Industrial & Systems          {}
# 133    IT|Software Development|Full-Stack Development          {}
# 138    IT|Software Development|Full-Stack Development          {}
# 141    IT|Software Development|Full-Stack Development          {}
# ...                                               ...         ...
# 2991                Business|Procurement|Supply Chain          {}
# 2992                Business|Procurement|Supply Chain          {}
# 3005         IT|IT Management|Enterprise Architecture          {}
# 3008  Public Sector & Non-Profit|Education & Research          {}
# 3009                 IT|IT Support|Helpdesk & Support          {}
#
#               languages  experience  \
# 106                None     3 years
# 113   [german, english]  5 years of
# 133                None        None
# 138   [german, english]        None
# 141   [german, english]        None
# ...                 ...         ...
# 2991  [german, english]        None
# 2992  [german, english]  5 years of
# 3005           [german]  5 years of
# 3008               None        None
# 3009               None        None
#
#                                                  degree  \
# 106                                                None
# 113   {'degree': 'degree', 'economic': 'field', 'eng...
# 133                                                None
# 138                                                None
# 141                                                None
# ...                                                 ...
# 2991                                               None
# 2992                                               None
# 3005                                               None
# 3008                                               None
# 3009                                               None
#
#                                      soft_skills skills
# 106                                 [leadership]     []
# 113                              [communication]     []
# 133                                         None     []
# 138                                 [initiative]     []
# 141                                 [initiative]     []
# ...                                          ...    ...
# 2991                [communication, open-minded]     []
# 2992                 [collaboration, creativity]     []
# 3005  [management, collaboration, communication]     []
# 3008                                [management]     []
# 3009                                        None     []
#
# [719 rows x 14 columns]

# %% [markdown]
# ## we can't do anything about the rest 719 rows they look good although they don't have requirements

# %% [markdown]
# #### now we deal with the degree and make other columns as dict or list types

# %%
df[df.degree != None]
# Out:
#                                                   title  \
# 0     Procurement Specialist Data Science Artificial...
# 1     Dhbw Studies - Data Science Artificial Intelli...
# 2                   Data Science Area Python Databricks
# 3     Dual Studies Data Science Artificial Intelligence
# 4     Dual Studies Data Science Artificial Intellige...
# ...                                                 ...
# 3020       Operations Manager Customer Service C24 Bank
# 3021                                    Cloud Architekt
# 3022  It Service Engineer-Analyst Smart Meter Softwa...
# 3023                                      It Specialist
# 3024                             It Security Consultant
#
#                                            company  \
# 0     Leadec Management Central Europe BV & Co. KG
# 1          Liebherr-International Deutschland GmbH
# 2                                          ARAG SE
# 3                                         Deloitte
# 4                           Lidl Stiftung & Co. KG
# ...                                            ...
# 3020                                       CHECK24
# 3021                                           ZDF
# 3022                                  Schleupen SE
# 3023  FERCHAU – Connecting People and Technologies
# 3024  FERCHAU – Connecting People and Technologies
#
#                              location                    job_type  \
# 0                           Stuttgart            Feste Anstellung
# 1                            Biberach                         NaN
# 2                          Düsseldorf  Studentenjobs, Werkstudent
# 3     Düsseldorf, Mannheim, Stuttgart         Ausbildung, Studium
# 4                          Neckarsulm         Ausbildung, Studium
# ...                               ...                         ...
# 3020                Frankfurt am Main            Feste Anstellung
# 3021                            Mainz            Feste Anstellung
# 3022                        Ettlingen            Feste Anstellung
# 3023                      Norderstedt            Feste Anstellung
# 3024                           Bremen            Feste Anstellung
#
#                    employment_type  \
# 0     Homeoffice möglich, Vollzeit
# 1                              NaN
# 2     Homeoffice möglich, Teilzeit
# 3                         Vollzeit
# 4                         Vollzeit
# ...                            ...
# 3020                      Vollzeit
# 3021            Teilzeit, Vollzeit
# 3022  Homeoffice möglich, Vollzeit
# 3023  Homeoffice möglich, Vollzeit
# 3024                      Vollzeit
#
#                                             description  \
# 0     With 14,500 employees worldwide and more than ...
# 1     Monari is a future-oriented and international ...
# 2     IONITY is a joint venture of the car manufactu...
# 3     ZS2Radätteilen GmbH is one of the leading Germ...
# 4     Everything started with an adhesive film. Toda...
# ...                                                 ...
# 3020  C24 Bank GmbH is part of the Check24 Group. Un...
# 3021  The Planning and Realization business area (PU...
# 3022  We are an innovative medium -sized software co...
# 3023  Combining people and technologies, designing t...
# 3024  Do you know that security comes first in today...
#
#                                            requirements  \
# 0     You bring many years of professional experienc...
# 1     Successfully completed degree in business info...
# 2     You have a successfully completed degree in th...
# 3     Completed scientific university studies in com...
# 4     A completed course of study in a relevant area...
# ...                                                 ...
# 3020  Completed studies (diploma [FH]/Bachelor) in t...
# 3021  You have a completed training as a bank clerk ...
# 3022  Completed vocational training as a specialist ...
# 3023  Completed university education at an applied u...
# 3024  You bring a good conclusion as a bachelor's ch...
#
#                                        job_category  \
# 0           Business|Procurement|Strategic Sourcing
# 1                         IT|Data & AI|Data Science
# 2                         IT|Data & AI|Data Science
# 3                         IT|Data & AI|Data Science
# 4                         IT|Data & AI|Data Science
# ...                                             ...
# 3020  IT|IT Management|Product & Project Management
# 3021            IT|DevOps & Cloud|Cloud Engineering
# 3022             Engineering|Electrical Engineering
# 3023              Customer Service|Client Relations
# 3024                  Legal|Compliance & Regulatory
#
#                                             hard_skills          languages  \
# 0     {'sql': 'databases', 'python': 'programming la...  [german, english]
# 1     {'python': 'programming languages', 'databrick...          [english]
# 2     {'programming language': 'other', 'data scienc...           [german]
# 3     {'devops/mlops': 'other', 'data science': 'dat...  [german, english]
# 4                 {'data science': 'data science & ai'}               None
# ...                                                 ...                ...
# 3020  {'java': 'programming languages', 'python': 'p...               None
# 3021                                                 {}               None
# 3022                      {'ms office': 'office tools'}               None
# 3023  {'outlook': 'office tools', 'excel': 'bi & ana...           [german]
# 3024                                                 {}               None
#
#      experience                                             degree  \
# 0          None  {'degree': 'degree', 'economic': 'field', 'eng...
# 1          None          {'degree': 'degree', 'business': 'field'}
# 2          None  {'degree': 'degree', 'computer science': 'field'}
# 3          None                                               None
# 4          None                                               None
# ...         ...                                                ...
# 3020       None  {'bachelor': 'degree', 'diploma': 'degree', 'd...
# 3021       None                                               None
# 3022       None                                               None
# 3023       None                                               None
# 3024       None                                               None
#
#                                   soft_skills  \
# 0                                [management]
# 1                             [communication]
# 2     [analytical, communication, initiative]
# 3                             [communication]
# 4                                [analytical]
# ...                                       ...
# 3020              [analytical, communication]
# 3021                          [communication]
# 3022              [management, communication]
# 3023                 [management, initiative]
# 3024                             [analytical]
#
#                                                  skills
# 0     [sql, python, programming language, data scien...
# 1     [python, databricks, spark, cloud computing, c...
# 2                  [programming language, data science]
# 3                          [devops/mlops, data science]
# 4                                        [data science]
# ...                                                 ...
# 3020  [java, python, sql, css, javascript, programmi...
# 3021                                            [cloud]
# 3022                                        [ms office]
# 3023                             [outlook, excel, word]
# 3024                                         [security]
#
# [2901 rows x 14 columns]

# %%
list(x for x in df.degree[3020].keys() if df.degree[3020].get(x) == 'degree')
# Out:
# ['bachelor', 'diploma', 'degree']

# %%
df.loc[df.degree.notnull(), "degree_type"] = \
df[df.degree.notnull()].degree.apply(lambda x : list(y for y in x.keys() if x.get(y) == "degree"))

# %%
df.loc[df.degree.notnull(), "degree_field"] = \
df[df.degree.notnull()].degree.apply(lambda x : list(y for y in x.keys() if x.get(y) == "field"))

# %% [markdown]
# ## now let's deal with the job_category for last

# %%
re.search(r"^([^|]+)", df.job_category[0]).group(1)
# Out:
# 'Business'

# %%
df.loc[:,"sub_category_1"] = df.job_category.apply(lambda x : re.search(r"^([^|]+)",x).group(1))

# %%
df.loc[:,"sub_category_2"] = df.job_category.apply(lambda x : re.search(r"^[^|]+(?:\|([^|]+))?", x).group(1))
# re.search(r"([^|]+)$", df.job_category[380]).group(1)
# df.job_category[2980]

# %%
df.loc[:, "sub_category_3"] = df.job_category.apply(lambda x : re.search(r"([^|]+)$",x).group(1))

# %% [markdown]
# # last cleaning of the data now

# %%
df = df.drop(columns=["description", "requirements", "job_category", "hard_skills", "degree"])

# %%
df
# Out:
#                                                   title  \
# 0     Procurement Specialist Data Science Artificial...
# 1     Dhbw Studies - Data Science Artificial Intelli...
# 2                   Data Science Area Python Databricks
# 3     Dual Studies Data Science Artificial Intelligence
# 4     Dual Studies Data Science Artificial Intellige...
# ...                                                 ...
# 3020       Operations Manager Customer Service C24 Bank
# 3021                                    Cloud Architekt
# 3022  It Service Engineer-Analyst Smart Meter Softwa...
# 3023                                      It Specialist
# 3024                             It Security Consultant
#
#                                            company  \
# 0     Leadec Management Central Europe BV & Co. KG
# 1          Liebherr-International Deutschland GmbH
# 2                                          ARAG SE
# 3                                         Deloitte
# 4                           Lidl Stiftung & Co. KG
# ...                                            ...
# 3020                                       CHECK24
# 3021                                           ZDF
# 3022                                  Schleupen SE
# 3023  FERCHAU – Connecting People and Technologies
# 3024  FERCHAU – Connecting People and Technologies
#
#                              location                    job_type  \
# 0                           Stuttgart            Feste Anstellung
# 1                            Biberach                         NaN
# 2                          Düsseldorf  Studentenjobs, Werkstudent
# 3     Düsseldorf, Mannheim, Stuttgart         Ausbildung, Studium
# 4                          Neckarsulm         Ausbildung, Studium
# ...                               ...                         ...
# 3020                Frankfurt am Main            Feste Anstellung
# 3021                            Mainz            Feste Anstellung
# 3022                        Ettlingen            Feste Anstellung
# 3023                      Norderstedt            Feste Anstellung
# 3024                           Bremen            Feste Anstellung
#
#                    employment_type          languages experience  \
# 0     Homeoffice möglich, Vollzeit  [german, english]       None
# 1                              NaN          [english]       None
# 2     Homeoffice möglich, Teilzeit           [german]       None
# 3                         Vollzeit  [german, english]       None
# 4                         Vollzeit               None       None
# ...                            ...                ...        ...
# 3020                      Vollzeit               None       None
# 3021            Teilzeit, Vollzeit               None       None
# 3022  Homeoffice möglich, Vollzeit               None       None
# 3023  Homeoffice möglich, Vollzeit           [german]       None
# 3024                      Vollzeit               None       None
#
#                                   soft_skills  \
# 0                                [management]
# 1                             [communication]
# 2     [analytical, communication, initiative]
# 3                             [communication]
# 4                                [analytical]
# ...                                       ...
# 3020              [analytical, communication]
# 3021                          [communication]
# 3022              [management, communication]
# 3023                 [management, initiative]
# 3024                             [analytical]
#
#                                                  skills  \
# 0     [sql, python, programming language, data scien...
# 1     [python, databricks, spark, cloud computing, c...
# 2                  [programming language, data science]
# 3                          [devops/mlops, data science]
# 4                                        [data science]
# ...                                                 ...
# 3020  [java, python, sql, css, javascript, programmi...
# 3021                                            [cloud]
# 3022                                        [ms office]
# 3023                             [outlook, excel, word]
# 3024                                         [security]
#
#                       degree_type  \
# 0                        [degree]
# 1                        [degree]
# 2                        [degree]
# 3                             NaN
# 4                             NaN
# ...                           ...
# 3020  [bachelor, diploma, degree]
# 3021                          NaN
# 3022                          NaN
# 3023                          NaN
# 3024                          NaN
#
#                                            degree_field    sub_category_1  \
# 0     [economic, engineering, computer science, busi...          Business
# 1                                            [business]                IT
# 2                                    [computer science]                IT
# 3                                                   NaN                IT
# 4                                                   NaN                IT
# ...                                                 ...               ...
# 3020                      [technical, computer science]                IT
# 3021                                                NaN                IT
# 3022                                                NaN       Engineering
# 3023                                                NaN  Customer Service
# 3024                                                NaN             Legal
#
#                sub_category_2                sub_category_3
# 0                 Procurement            Strategic Sourcing
# 1                   Data & AI                  Data Science
# 2                   Data & AI                  Data Science
# 3                   Data & AI                  Data Science
# 4                   Data & AI                  Data Science
# ...                       ...                           ...
# 3020            IT Management  Product & Project Management
# 3021           DevOps & Cloud             Cloud Engineering
# 3022   Electrical Engineering        Electrical Engineering
# 3023         Client Relations              Client Relations
# 3024  Compliance & Regulatory       Compliance & Regulatory
#
# [2901 rows x 14 columns]

# %%
pd.set_option('display.max_rows', 150)
df.experience.value_counts()
# Out:
# experience
# 5 years of                 46
# 2 years of                 41
# 3 years of                 41
# 3 years of experience      37
# 5 years                    34
# 5+ years of experience     28
# 3 years                    25
# 5 years of experience      25
# 2 years of experience      23
# 3+ years of experience     22
# 6 months                   14
# 3+ years of                14
# 5+ years of                14
# 10 years of experience     13
# 2 years                    13
# 2+ years                   12
# 10 years of                12
# 10+ years                  11
# 4 years of                 11
# 1 year                      8
# 5+ years                    7
# 10+ years of experience     7
# 2+ years of                 6
# 8 years of                  6
# 3+ years                    6
# 4 years of experience       6
# 2+ years of experience      5
# 5 years experience          5
# 4+ years of                 5
# 10+ years of                5
# 7 years of                  5
# 4 years                     5
# 6+ years of experience      4
# 8 years                     4
# 4+ years of experience      4
# 1 year of                   4
# 12 months                   4
# 3 years of work             4
# 8+ years of experience      4
# 4+ years                    3
# 8 years of experience       3
# 5 years of work             3
# 8+ years of                 3
# 7+ years of                 3
# 2 years experience          3
# 7+ years of experience      3
# 6 years of experience       3
# 2 years of work             3
# 1 year of experience        3
# 3 months                    3
# 6 years of                  3
# 1 years of                  3
# 11+ yrs                     3
# 5 years work                3
# 4 Years of experience       2
# 5 year                      2
# 6 years                     2
# 5+ years of work            2
# 1+ year                     2
# 18 years of                 2
# 7 years of experience       2
# 3+ years experience         2
# 7+ years                    2
# 10 years                    2
# 2+ years experience         2
# 7 years                     2
# 3 yearsExperience           2
# 9 years of                  2
# 1 years of experience       2
# 15+ years of                2
# 3+ years of work            1
# 2 year of                   1
# 6 months of                 1
# 5 Years of experience       1
# 4+ years of work            1
# 3 year                      1
# 2+yearsofexperience         1
# 8+ years                    1
# 6+ years of                 1
# 6 years work                1
# 45 years                    1
# 10+ years work              1
# 5 yearsof                   1
# 28 years of                 1
# 32 years of experience      1
# 3 years ofexperience        1
# 4 years of work             1
# 2 Years of Experience       1
# 12+ years of experience     1
# 4+ years experience         1
# 3years                      1
# 8 years of work             1
# 2 yearsof                   1
# 5+ yearsof experience       1
# 15 years experience         1
# 1+ years of                 1
# 1 year experience           1
# 5+ years experience         1
# 3 months of                 1
# 2+ years ofexperience       1
# 4 years experience          1
# 12 month                    1
# 5+ years Experience         1
# 7 Years                     1
# 5 yrs                       1
# 1+ years experience         1
# 2 years work                1
# 5 yearsExperience           1
# 7+ years of work            1
# 12+ months                  1
# 2+ Years of                 1
# 5+ Years                    1
# Name: count, dtype: int64

# %%
def clean_experience(text):
    if not isinstance(text, str) or not text.strip():
        return None
    
    # Match numbers with optional units (years/months)
    match = re.search(
        r"(\d+)\+?\s*(?:years?|yrs?|months?|mos?|y|m)?\b", 
        text, 
        flags=re.IGNORECASE
    )
    if not match:
        return None
    
    num = match.group(1)  # Extract number (e.g., "5")
    
    # Determine unit (default to years if ambiguous)
    if re.search(r"months?|mos?|m\b", text, re.IGNORECASE):
        unit = "m"
    else:
        unit = "y"  # Default to years
    
    return f"{num}{unit}"

# %%
df["experience_periode"] = df.experience.apply(clean_experience)

# %%
df= df.drop(columns=["experience"],axis=1)

# %%
df.job_type.value_counts()
# Out:
# job_type
# Feste Anstellung                                                                      2326
# Studentenjobs, Werkstudent                                                             168
# Ausbildung, Studium                                                                    142
# Befristeter Vertrag                                                                     96
# Praktikum                                                                               72
# Berufseinstieg/Trainee                                                                  16
# Berufseinstieg/Trainee, Feste Anstellung                                                14
# Praktikum, Studentenjobs, Werkstudent                                                   11
# Promotion/Habilitation                                                                   9
# Freie Mitarbeit/Projektmitarbeit                                                         8
# Bachelor-/Master-/Diplom-Arbeiten                                                        7
# Arbeitnehmerüberlassung                                                                  4
# Bachelor-/Master-/Diplom-Arbeiten, Praktikum                                             3
# Handelsvertreter                                                                         1
# Ausbildung, Studium, Bachelor-/Master-/Diplom-Arbeiten, Studentenjobs, Werkstudent       1
# Befristeter Vertrag, Feste Anstellung                                                    1
# Ausbildung, Studium, Feste Anstellung                                                    1
# Name: count, dtype: int64

# %%
df.employment_type.value_counts()
# Out:
# employment_type
# Homeoffice möglich, Vollzeit              1349
# Vollzeit                                  1018
# Homeoffice möglich, Teilzeit, Vollzeit     203
# Homeoffice möglich, Teilzeit               118
# Teilzeit                                   117
# Teilzeit, Vollzeit                          75
# Homeoffice möglich                           1
# Name: count, dtype: int64

# %%
df.loc[:,"Homeoffice"] = df.employment_type.str.contains("Homeoffice",case= False, na= False)

# %%
df.loc[:,"teilzeit"] = df.employment_type.str.contains("Teilzeit",case = False, na= False)
df.loc[:,"Vollzeit"] = df.employment_type.str.contains("Vollzeit", case = False, na=False)

# %%
df = df.drop(columns=["employment_type"],axis=1)

# %%
df.job_type.value_counts()
# Out:
# job_type
# Feste Anstellung                                                                      2326
# Studentenjobs, Werkstudent                                                             168
# Ausbildung, Studium                                                                    142
# Befristeter Vertrag                                                                     96
# Praktikum                                                                               72
# Berufseinstieg/Trainee                                                                  16
# Berufseinstieg/Trainee, Feste Anstellung                                                14
# Praktikum, Studentenjobs, Werkstudent                                                   11
# Promotion/Habilitation                                                                   9
# Freie Mitarbeit/Projektmitarbeit                                                         8
# Bachelor-/Master-/Diplom-Arbeiten                                                        7
# Arbeitnehmerüberlassung                                                                  4
# Bachelor-/Master-/Diplom-Arbeiten, Praktikum                                             3
# Handelsvertreter                                                                         1
# Ausbildung, Studium, Bachelor-/Master-/Diplom-Arbeiten, Studentenjobs, Werkstudent       1
# Befristeter Vertrag, Feste Anstellung                                                    1
# Ausbildung, Studium, Feste Anstellung                                                    1
# Name: count, dtype: int64

# %%
df.loc[df.job_type.notna(),"job_type"] = df[df.job_type != None].job_type.apply(lambda x : list(item.strip() for item in str(x).split(",")))

# %%
df.loc[df.sub_category_2.isna(),"sub_category_2"]= df[df.sub_category_2.isna()].sub_category_3

# %%
df.isna().sum()
# Out:
# title                    0
# company                  0
# location                 2
# job_type                21
# languages             1185
# soft_skills            834
# skills                   0
# degree_type           1785
# degree_field          1785
# sub_category_1           0
# sub_category_2           0
# sub_category_3           0
# experience_periode    2242
# Homeoffice               0
# teilzeit                 0
# Vollzeit                 0
# dtype: int64

# %%
df.to_csv("clean_data.csv")
