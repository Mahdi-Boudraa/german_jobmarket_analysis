# %%
import pandas as pd
import spacy
from spacy.matcher import PhraseMatcher
import re
from typing import Optional

# %%
df = pd.read_csv("job_postings.csv")

# %%
def clean_job_title(title: str) -> str:
    """
    Cleans job titles by removing:
    - Gender markers (m/w/d, m/f/d, etc.)
    - Position levels (Senior, Junior, etc.)
    - Apprenticeship/study indicators
    - Special characters and extra whitespace
    - Location information
    - Percentage indicators
    - Years (2025, 2026, etc.)
    - Common small words (and, from, a, etc.)
    """
    original_title = title
    if not isinstance(title, str):
        return title
    
    # Convert to lowercase for consistent processing
    title = title.lower()
    
    # Remove gender markers and diversity indicators
    title = re.sub(
        r'\(?(m[\/\s]?[fw][\/\s]?d|f[\/\s]?m[\/\s]?d|all genders welcome|diverse|w[\/\s]?m[\/\s]?d|any gender)\)?',
        '', 
        title,
        flags=re.IGNORECASE
    )
    
    # Remove position levels (optional - keep if important for classification)
    title = re.sub(
        r'\b(senior|junior|lead|principal|associate|entry-level|mid-level|experienced|chief|head of)\b',
        '', 
        title
    )
    
    # Remove apprenticeship/study indicators
    title = re.sub(
        r'\b(azubi|apprentice|ausbildung|dual(?:es)? (?:study|studium)|werkstudent|working student|work student|student|practicum|internship|trainee)\b',
        '',
        title
    )
    
    # Remove years and percentages
    title = re.sub(r'(20[0-9]{2}|[0-9]{4})', '', title)
    title = re.sub(r'[0-9]{1,3}\s?%', '', title)
    
    # Remove location information (in brackets/parentheses)
    title = re.sub(r'\([^)]*\)', '', title)  # Remove everything in parentheses
    title = re.sub(r'\[[^\]]*\]', '', title)  # Remove everything in brackets
    title = re.sub(r'\bat\b.*$', '', title)   # Remove "at location" clauses
    title = re.sub(r'\bstandort\b.*$', '', title)  # Remove German location indicators
    
    # Remove special characters except hyphens (for compound terms)
    title = re.sub(r'[^\w\s-]', ' ', title)
    
    # Remove common small words
    title = re.sub(r'\b(and|from|a|an|the|in|of|for|with|on|at|as)\b', '', title)
    
    # Remove common corporate jargon
    jargon = [
        'focus on', 'focus', 'area of', 'in the area', 'field of', 
        'with specialization', 'specializing in', 'specialist for',
        'compulsory', 'limited', 'part-time', 'full-time',
        'remote', 'hybrid', 'onsite', 'hiring', 'position',
        'opportunity', 'role', 'job', 'early', 'start of', 'key',
        'corporate', 'Specialist', 'Area', 'teacher', 'professor'
    ]
    for term in jargon:
        title = title.replace(term, '')
    
    # Standardize common variations
    replacements = {
        r'\beng\b': 'engineer',
        r'\bdev\b': 'developer',
        r'\bmgr\b': 'manager',
        r'\bdir\b': 'director',
        r'\bvp\b': 'vice president',
        r'\bpm\b': 'project manager',
        r'\bki\b': 'artificial intelligence',
        r'\bai\b': 'artificial intelligence'
    }
    for pattern, replacement in replacements.items():
        title = re.sub(pattern, replacement, title)

    title = re.sub(r'\s+', ' ', title).strip()
    if not title:  # Fallback if we accidentally removed everything
        return original_title[:50].strip()
    
    # Remove department/division names
    title = re.sub(r'\b(group|department|division|team|center)\b.*$', '', title)
    
    title = title.title()  # Capitalize first letters (optional)
    
    
    return title

# %%
# Cleaning the data from unnecessary information

df["title"] = df.title.apply(clean_job_title)

# %%
# Load the language model
nlp = spacy.load("en_core_web_lg")

# Define the hierarchical job taxonomy
JOB_TAXONOMY = {
    "IT": {
        "Software Development": {
            "Frontend Development": [
                "frontend developer", "react engineer", "ui developer", "javascript specialist",
                "vue developer", "angular developer", "web developer"
            ],
            "Backend Development": [
                "backend engineer", "api developer", "java developer", "python developer",
                "golang developer", "nodejs developer", "spring boot engineer", "backend developer"
            ],
            "Full-Stack Development": [
                "full-stack developer", "mean stack engineer", "mern stack engineer",
                "software engineer", "web engineer", "Software Developer", "computer science"
            ],
            "Mobile Development": [
                "ios developer", "android developer", "flutter engineer", "react native developer",
                "mobile application developer", "kotlin developer", "swift developer"
            ],
            "Game Development": [
                "game developer", "unity engineer", "unreal engine programmer", "game designer", "level designer"
            ]
        },
        "DevOps & Cloud": {
            "DevOps Engineering": [
                "devops engineer", "site reliability engineer", "sre", "ci/cd specialist",
                "platform engineer", "automation engineer"
            ],
            "Cloud Engineering": [
                "aws engineer", "azure cloud architect", "google cloud engineer",
                "cloud solutions architect", "cloud infrastructure engineer"
            ],
            "Infrastructure & Networking": [
                "network engineer", "systems administrator", "it infrastructure manager",
                "network architect", "it systems engineer", "vpn specialist" 
            ]
        },
        "Data & AI": {
            "Data Science": [
                "data scientist", "machine learning engineer", "ai researcher",
                "statistical modeler", "data mining specialist", "data science"
            ],
            "Data Engineering": [
                "data engineer", "etl developer", "big data architect","data pipeline"
                "spark developer", "snowflake engineer", "delta lake specialist", "data warehouse"
            ],
            "Data Analysis": [
                "data analyst", "data analysis", "data management"
            ],
            "BI":[
                "bi","dashboard", "power bi developer", "tableau developer", "dax specialist", "business analyst"
                "business intelligence analyst", "bi developer", "business intelligence", "business analysis"
                "powerbi", "power bi", "tableau", "data visualization", "visualization"
            ],
            "AI, LLM & NLP": [
                "nlp engineer", "computer vision engineer", "deep learning specialist",
                "llm engineer", "genai engineer", "prompt engineer", "cv engineer", "ki",
            ],
            "Machine Learning":[
                "machine learning", "regression", "supervised learning", "unsupervised learning",
                "scikit learn", "pandas", "numpy", "matplotlib", "seaborn"
            ],
        },
        "Cybersecurity": {
            "Security Engineering": [
                "cybersecurity engineer", "penetration tester", "ethical hacker",
                "red team engineer", "blue team analyst"
            ],
            "Security Operations": [
                "soc analyst", "threat intelligence specialist", "incident responder",
                "forensics analyst", "malware analyst"
            ],
            "Governance & Compliance": [
                "security compliance manager", "risk analyst", "grc specialist",
                "it auditor", "iso 27001 consultant", "gdpr officer"
            ]
        },
        "IT Management": {
            "Engineering Leadership": [
                "engineering manager", "vp of engineering", "cto", "tech lead", "team lead"
            ],
            "Product & Project Management": [
                "technical product manager", "it project manager", "scrum master",
                "agile coach", "release manager", "delivery manager"
            ],
            "Enterprise Architecture": [
                "solution architect", "enterprise architect", "technical architect"
            ]
        },
        "QA & Testing": {
            "Manual Testing": [
                "qa tester", "test analyst", "software tester"
            ],
            "Automation Testing": [
                "qa automation engineer", "sdet", "performance tester",
                "selenium engineer", "test automation architect"
            ],
            "QA Management": [
                "qa manager", "test lead", "qa coordinator"
            ]
        },
        "IT Support": {
            "Helpdesk & Support": [
                "it support specialist", "helpdesk technician", "desktop support",
                "first level support", "second level support", "technischer support"
            ],
            "Database Administration": [
                "dba", "sql developer", "database architect", "postgres admin", "mysql expert"
            ],
            "ERP & Business Systems": [
                "sap consultant", "sap developer", "sap basis administrator",
                "salesforce admin", "crm consultant", "microsoft dynamics consultant", "Digital Network"
            ]
        }
    },
    "Business": {
        "Finance": {
            "Accounting": [
                "accountant", "financial analyst", "auditor", "buchhalter", "controller"
            ],
            "Banking & Investment": [
                "investment banker", "financial advisor", "risk manager", "credit analyst"
            ]
        },
        "Sales & Marketing": {
            "Sales": [
                "sales executive", "account manager", "business development",
                "vertrieb", "sales consultant", "presales engineer"
            ],
            "Digital Marketing": [
                "seo specialist", "ppc manager", "growth marketer",
                "performance marketer", "online marketing manager"
            ]
        },
        "HR": {
            "Recruitment": [
                "technical recruiter", "hr business partner", "talent acquisition specialist"
            ],
            "HR Operations": [
                "hr manager", "payroll specialist", "hr generalist", "personalsachbearbeiter"
            ]
        },
        "Administration & Legal": {
            "Office Administration": ["office manager", "executive assistant", "administrative coordinator"],
            "Legal & Compliance": ["legal counsel", "compliance officer", "contract manager"]
        },
        "Procurement": {
            "Strategic Sourcing": ["procurement specialist", "buyer"],
            "Supply Chain": ["supply chain manager", "logistics"],
            "Vendor Management": ["vendor development", "supplier manager"]
        },
        "Finance": {
            "Wealth Management": ["private wealth", "portfolio manager"],
            "Corporate Finance": ["mergers acquisitions", "m&a"],
            "Risk Management": ["risk controller", "insurance risk"]
        }
    },
    "Engineering": {
        "Mechanical Engineering": ["mechanical engineer", "mechatronics engineer"],
        "Electrical Engineering": ["electrical engineer", "power systems engineer"],
        "Civil & Structural": ["civil engineer", "structural engineer", "construction engineer"],
        "Automotive & Aerospace": ["automotive engineer", "aerospace engineer", "vehicle dynamics specialist"],
        "Chemical & Process": ["chemical engineer", "process engineer", "materials engineer"],
        "Industrial & Systems": ["industrial engineer", "manufacturing engineer", "systems engineer", "system engineer",
                                "production technology", "plant mechanic", "coating technology", "process specialist",
                                "quality engineer", "testing specialist"]
    },
    "Healthcare": {
        "Medical Practice": ["doctor", "physician", "surgeon", "general practitioner"],
        "Nursing": ["nurse", "registered nurse", "icu nurse"],
        "Therapy & Support": ["physiotherapist", "occupational therapist", "speech therapist"],
        "Pharmacy & Labs": ["pharmacist", "lab technician", "clinical researcher"],
        "Public Health": ["epidemiologist", "health policy analyst", "public health nurse"]
    },
    "Education": {
        "School Teaching": ["primary school teacher", "secondary school teacher", "special education teacher"],
        "University & Research": ["lecturer", "professor", "research associate"],
        "Training & eLearning": ["corporate trainer", "instructional designer", "elearning specialist"]
    },
    "Logistics & Supply Chain": {
        "Logistics Management": ["logistics manager", "warehouse manager", "supply chain planner"],
        "Transportation": ["delivery driver", "truck driver", "logistics coordinator"],
        "Procurement & Planning": ["procurement officer", "demand planner", "inventory controller"]
    },
    "Manufacturing & Production": {
        "Plant Operations": ["production operator", "plant supervisor", "machinist"],
        "Maintenance": ["maintenance technician", "electromechanic", "industrial mechanic"],
        "Quality Control": ["quality inspector", "qa technician", "qc analyst"]
    },
    "Construction & Skilled Trades": {
        "Construction": ["construction worker", "site manager", "bricklayer"],
        "Skilled Trades": ["electrician", "plumber", "carpenter", "welder"],
        "Project Management": ["construction project manager", "site supervisor"]
    },
    "Media & Design": {
        "Graphic & Visual Design": ["graphic designer", "ui/ux designer", "motion designer"],
        "Content & Writing": ["copywriter", "content writer", "technical writer"],
        "Marketing & PR": ["brand manager", "pr specialist", "communications officer"]
    },
    "Legal": {
        "Legal Practice": ["lawyer", "solicitor", "barrister", "legal advisor"],
        "Legal Support": ["paralegal", "legal assistant", "contract administrator"],
        "Compliance & Regulatory": ["compliance officer", "data protection officer"]
    },
    "Customer Service": {
        "Call Center": ["customer service representative", "call center agent", "support agent"],
        "Client Relations": ["account coordinator", "customer success manager", "support specialist"]
    },
    "Public Sector & Non-Profit": {
        "Government": ["civil servant", "policy advisor", "administrative officer"],
        "NGO & Charity": ["program coordinator", "fundraiser", "non-profit manager"],
        "Education & Research": ["public research analyst", "education officer"]
    },
    "Hospitality & Tourism": {
        "Hotel & Restaurant": ["receptionist", "chef", "waiter", "hotel manager"],
        "Travel Services": ["travel agent", "tour guide", "concierge"]
    },
    "Retail & Consumer": {
        "Retail Sales": ["retail assistant", "store manager", "cashier"],
        "Inventory & Merchandising": ["stock clerk", "visual merchandiser", "inventory specialist"]
    },
    "Project Manager":{
        "project manager", "project management", "Projektmanager"
    }

}


class JobTitleClassifier:
    def __init__(self):
        self.matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
        self._build_matcher()
        
    def _build_matcher(self):
        """Build phrase matcher from taxonomy"""
        for main_cat, subcats in JOB_TAXONOMY.items():
            if isinstance(subcats, dict):
                for subcat, subsubcats in subcats.items():
                    if isinstance(subsubcats, dict):
                        for subsubcat, terms in subsubcats.items():
                            patterns = [nlp(text) for text in terms]
                            self.matcher.add(f"{main_cat}|{subcat}|{subsubcat}", patterns)
                    else:
                        patterns = [nlp(text) for text in subsubcats]
                        self.matcher.add(f"{main_cat}|{subcat}", patterns)
    
    def classify(self, title):
        """Classify a job title into the hierarchy"""
        doc = nlp(title.lower())
        matches = self.matcher(doc)
        
        if matches:
            # Get the most specific match (longest path)
            match_ids = [nlp.vocab.strings[match_id] for match_id, _, _ in matches]
            return max(match_ids, key=lambda x: len(x.split("|")))
        
        # Fallback: Use similarity for unclassified titles
        return self._classify_with_similarity(title)
    
    def _classify_with_similarity(self, title):
        """Fallback classifier using semantic similarity"""
        doc = nlp(title.lower())
        best_score = 0
        best_category = "Other"
        
        # Flatten taxonomy for similarity comparison
        flat_taxonomy = {}
        for main_cat, subcats in JOB_TAXONOMY.items():
            if isinstance(subcats, dict):
                for subcat, subsubcats in subcats.items():
                    if isinstance(subsubcats, dict):
                        for subsubcat, terms in subsubcats.items():
                            for term in terms:
                                flat_taxonomy[f"{main_cat}|{subcat}|{subsubcat}"] = term
                    else:
                        for term in subsubcats:
                            flat_taxonomy[f"{main_cat}|{subcat}"] = term
        
        # Compare with all terms
        for category, example in flat_taxonomy.items():
            example_doc = nlp(example)
            similarity = doc.similarity(example_doc)
            if similarity > best_score and similarity > 0.7:
                best_score = similarity
                best_category = category
        
        return best_category

# Example usage
classifier = JobTitleClassifier()

# titles = clean_titles

# for title in titles:
# classification = classifier.classify(title)
    # print(f"{title: <30} => {classification}")

# %%
#  applying the best classifier for the the job type

classification = df.title.apply(classifier.classify)
# Out:
# /var/folders/5w/y91gtvg50551n3s4nv78b_q00000gn/T/ipykernel_30222/3731998240.py:286: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = doc.similarity(example_doc)

# %%
df["job_category"] = classification

# %%
df.job_category.value_counts()
# Out:
# job_category
# Other                                             1706
# IT|Data & AI|Data Analysis                         450
# Business|Sales & Marketing|Digital Marketing       259
# IT|Software Development|Full-Stack Development     225
# Business|Sales & Marketing|Sales                   136
#                                                   ...
# IT|Data & AI|AI, LLM & NLP                           1
# Manufacturing & Production|Quality Control           1
# IT|Software Development|Mobile Development           1
# Retail & Consumer|Retail Sales                       1
# Engineering|Automotive & Aerospace                   1
# Name: count, Length: 74, dtype: int64

# %%
# Out:
# <bound method Series.count of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4544    False
# 4545    False
# 4546    False
# 4547    False
# 4548    False
# Name: job_category, Length: 4516, dtype: bool>

# %%
other_category = df[df.job_category == "Other"]
df1 = df.copy()

# %%
df1[(df1.job_category == "Other") & (df1.title.str.contains("artificial intelligence", case=False))] = \
other_category[other_category.title.str.contains("Artificial Intelligence")].replace("Other", "IT|Data & AI|AI, LLM & NLP")

# %%
df1[df1.title.str.contains("Artificial Intelligence")]
# Out:
#                                                   title  \
# 1     Procurement Specialist Data Science Artificial...
# 2     Dhbw Studies - Data Science Artificial Intelli...
# 4     Dual Studies Data Science Artificial Intelligence
# 5     Dual Studies Data Science Artificial Intellige...
# 8                  Data Science Artificial Intelligence
# ...                                                 ...
# 4285  Artificial Intelligence Ml Engineer - Nlp Llm ...
# 4360  Research Staff-Artificial Intelligence Scienti...
# 4402  Artificial Intelligence Research Engineer - Ar...
# 4420   Founders - Artificial Intelligence Ml Consulting
# 4528       Artificial Intelligence Digitization Officer
#
#                                                 company  \
# 1          Leadec Management Central Europe BV & Co. KG
# 2               Liebherr-International Deutschland GmbH
# 4                                              Deloitte
# 5                                Lidl Stiftung & Co. KG
# 8                           Schwarz Corporate Solutions
# ...                                                 ...
# 4285                                        Cinemo GmbH
# 4360  Hochschule Mittweida University Of Applied Sci...
# 4402                                       Helsing GmbH
# 4420                                        Code17 GmbH
# 4528                                    Stadt Weinstadt
#
#                              location             job_type  \
# 1                           Stuttgart     Feste Anstellung
# 2                            Biberach                  NaN
# 4     Düsseldorf, Mannheim, Stuttgart  Ausbildung, Studium
# 5                          Neckarsulm  Ausbildung, Studium
# 8               Neckarsulm, Heilbronn  Ausbildung, Studium
# ...                               ...                  ...
# 4285                           Hybrid     Feste Anstellung
# 4360                        Mittweida  Befristeter Vertrag
# 4402                          München     Feste Anstellung
# 4420                          Leipzig     Feste Anstellung
# 4528          Weinstadt bei Stuttgart     Feste Anstellung
#
#                    employment_type  \
# 1     Homeoffice möglich, Vollzeit
# 2                              NaN
# 4                         Vollzeit
# 5                         Vollzeit
# 8                         Vollzeit
# ...                            ...
# 4285                      Vollzeit
# 4360  Homeoffice möglich, Teilzeit
# 4402                      Vollzeit
# 4420  Homeoffice möglich, Vollzeit
# 4528                      Teilzeit
#
#                                             description  \
# 1     With 14,500 employees worldwide and more than ...
# 2     Monari is a future-oriented and international ...
# 4     ZS2Radätteilen GmbH is one of the leading Germ...
# 5     Everything started with an adhesive film. Toda...
# 8     Our over 30-year success story in the software...
# ...                                                 ...
# 4285  Upvest is on a mission to make investing as ea...
# 4360  The University of Mittweida, University of App...
# 4402  At Helsing we deliver AI-based capabilities an...
# 4420  As a lean, bootstrapped team of 12, Code17 Gmb...
# 4528  KI and digitization officer (m/f/d) Weinstadt-...
#
#                                            requirements  \
# 1     You bring many years of professional experienc...
# 2     Successfully completed degree in business info...
# 4     Completed scientific university studies in com...
# 5     A completed course of study in a relevant area...
# 8     A successfully completed degree in the field o...
# ...                                                 ...
# 4285  You have a completed tax consultant exam or ar...
# 4360  · Completed scientific university degree / com...
# 4402  Your profileYou’re passionate about innovative...
# 4420  At least 2 years of successfully completed tra...
# 4528  You have completed a degree or further trainin...
#
#                                  job_category
# 1     Business|Procurement|Strategic Sourcing
# 2                   IT|Data & AI|Data Science
# 4                   IT|Data & AI|Data Science
# 5                   IT|Data & AI|Data Science
# 8                   IT|Data & AI|Data Science
# ...                                       ...
# 4285               IT|Data & AI|AI, LLM & NLP
# 4360          Education|University & Research
# 4402               IT|Data & AI|AI, LLM & NLP
# 4420               IT|Data & AI|AI, LLM & NLP
# 4528               IT|Data & AI|AI, LLM & NLP
#
# [166 rows x 8 columns]

# %%
df = df1
df
# Out:
#                                                   title  \
# 0                                Business Analyst - Im
# 1     Procurement Specialist Data Science Artificial...
# 2     Dhbw Studies - Data Science Artificial Intelli...
# 3                   Data Science Area Python Databricks
# 4     Dual Studies Data Science Artificial Intelligence
# ...                                                 ...
# 4544                                      It Specialist
# 4545  Project Coordinator Formulation Process Develo...
# 4546               Quercomers Production Pharmaceutical
# 4547                                   Laborant Cta Bta
# 4548                             It Security Consultant
#
#                                            company  \
# 0                                   Markant Gruppe
# 1     Leadec Management Central Europe BV & Co. KG
# 2          Liebherr-International Deutschland GmbH
# 3                                          ARAG SE
# 4                                         Deloitte
# ...                                            ...
# 4544  FERCHAU – Connecting People and Technologies
# 4545  FERCHAU – Connecting People and Technologies
# 4546  FERCHAU – Connecting People and Technologies
# 4547  FERCHAU – Connecting People and Technologies
# 4548  FERCHAU – Connecting People and Technologies
#
#                              location                    job_type  \
# 0                           Offenburg            Feste Anstellung
# 1                           Stuttgart            Feste Anstellung
# 2                            Biberach                         NaN
# 3                          Düsseldorf  Studentenjobs, Werkstudent
# 4     Düsseldorf, Mannheim, Stuttgart         Ausbildung, Studium
# ...                               ...                         ...
# 4544                      Norderstedt            Feste Anstellung
# 4545              Biberach an der Riß            Feste Anstellung
# 4546              Biberach an der Riß            Feste Anstellung
# 4547              Biberach an der Riß            Feste Anstellung
# 4548                           Bremen            Feste Anstellung
#
#                    employment_type  \
# 0     Homeoffice möglich, Vollzeit
# 1     Homeoffice möglich, Vollzeit
# 2                              NaN
# 3     Homeoffice möglich, Teilzeit
# 4                         Vollzeit
# ...                            ...
# 4544  Homeoffice möglich, Vollzeit
# 4545                      Vollzeit
# 4546                      Vollzeit
# 4547                      Vollzeit
# 4548                      Vollzeit
#
#                                             description  \
# 0     There is a lot of know-how in our medium-sized...
# 1     With 14,500 employees worldwide and more than ...
# 2     Monari is a future-oriented and international ...
# 3     IONITY is a joint venture of the car manufactu...
# 4     ZS2Radätteilen GmbH is one of the leading Germ...
# ...                                                 ...
# 4544  Combining people and technologies, designing t...
# 4545  You don't want to leave your career developmen...
# 4546  You don't want to leave your career developmen...
# 4547  Finding the best minds for a wide variety of t...
# 4548  Do you know that security comes first in today...
#
#                                            requirements  \
# 0     Ongoing studies in the field of computer scien...
# 1     You bring many years of professional experienc...
# 2     Successfully completed degree in business info...
# 3     You have a successfully completed degree in th...
# 4     Completed scientific university studies in com...
# ...                                                 ...
# 4544  Completed university education at an applied u...
# 4545  Practice from the user support: You have well-...
# 4546  Technical basis with depth: You have several y...
# 4547  Completed training as an IT system administrat...
# 4548  You bring a good conclusion as a bachelor's ch...
#
#                                   job_category
# 0     Public Sector & Non-Profit|NGO & Charity
# 1      Business|Procurement|Strategic Sourcing
# 2                    IT|Data & AI|Data Science
# 3                    IT|Data & AI|Data Science
# 4                    IT|Data & AI|Data Science
# ...                                        ...
# 4544         Customer Service|Client Relations
# 4545                                     Other
# 4546                                     Other
# 4547                                     Other
# 4548             Legal|Compliance & Regulatory
#
# [4549 rows x 8 columns]

# %%
indexes_to_drop = df[(df.job_category == "Other") & (df.title.str.contains("data", case = False))].index

# %%
df.drop(indexes_to_drop, inplace = True)

# %%
pattern = r"projektmanager|project manager|project management"

mask = (df.job_category == "Other") & (df.title.str.contains(pattern, case=False))
df.loc[mask, 'job_category'] = "Project Manager"

# %%
# Dealing with other job category
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from collections import Counter

nltk.download('stopwords')
stemmer = PorterStemmer()

# Custom stopwords
custom_stopwords = set(stopwords.words('english'))

def process_text(text):
    text = str(text).lower()
    words = re.findall(r'\b[a-z]{2,}\b', text)  # Only words with 2+ letters
    words = [stemmer.stem(w) for w in words if w not in custom_stopwords]
    return words

all_words = []
for title in df[df['job_category'] == 'Other']['title']:
    all_words.extend(process_text(title))

word_counts = Counter(all_words)
word_freq = pd.DataFrame(word_counts.most_common(30), 
                        columns=['word', 'count'])

# Visualization
plt.figure(figsize=(12, 6))
word_freq.set_index('word')['count'].plot(kind='bar')
plt.title('Top 30 Words in "Other" Job Titles')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /Users/mac/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
mask = (df.job_category == "Other")
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4544    False
# 4545     True
# 4546     True
# 4547     True
# 4548    False
# Name: job_category, Length: 4516, dtype: bool

# %%
def title_cleaning_other(title):
    stems = [
        r'consult', r'manag', r'develop', r'engin',    
        r'sale', r'account', r'sap', r'intern',
        r'specialist', r'product', r'employe',
        r'control', r'oper', r'administr',
        r'area', r'expert', r'system', 'servic'
        
    ]
    pattern = r'\b\w*(' + '|'.join(stems) + r')\w*\b'
    cleaned_title = re.sub(pattern, '', title, flags=re.IGNORECASE)
    cleaned_title = re.sub(r'\s+', ' ', cleaned_title).strip()
    
    return cleaned_title

# %%
# first we clean the titles
df2 = df[mask].title.apply(title_cleaning_other)
# then we classify them again
# df_temp["job_category"] = df_temp.title.apply(classifier.classify)

# %%
df2 = pd.DataFrame(df2,columns=["title"])

# %%
drop_empty_index = df2[df2["title"].fillna("").str.len() == 0].index

# %%
df2.drop(drop_empty_index, inplace = True)

# %%
# df.drop(drop_empty_index, inplace = True)

# %%
all_words = []
for title in df2.title :
    all_words.extend(process_text(title))

word_counts = Counter(all_words)
word_freq = pd.DataFrame(word_counts.most_common(30), 
                        columns=['word', 'count'])

# Visualization
plt.figure(figsize=(12, 6))
word_freq.set_index('word')['count'].plot(kind='bar')
plt.title('Top 30 Words in "Other" Job Titles')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df2.title
# Out:
# 66      Final Thesis Validation Routing Algorithm Betw...
# 70                                      Programming Tutor
# 74                                                Content
# 77                        Insurance Mathematician Acarrow
# 80                                     Telecommunications
#                               ...
# 4540                 Digital Customer Experience C24 Bank
# 4543                           Credit Collection C24 Bank
# 4545              Project Coordinator Formulation Process
# 4546                            Quercomers Pharmaceutical
# 4547                                     Laborant Cta Bta
# Name: title, Length: 1481, dtype: object

# %%
pd.set_option('display.max_rows', 200)
df2.sample(200, random_state=1,)
# most of these jobs are junk jobs not related to the study
# Out:
#                                                   title
# 1154                                 Finance Part -Time
# 3098                                         Breafinery
# 517                                New Processing Pilot
# 3420                       Natural Scientist Technician
# 1944                                         Analyst Fp
# 3144                                    Move World - Or
# 4473                            Application Ux Designer
# 1534                    Application Technologist Baking
# 1389                             Abap Entwickler - Abap
# 3408  Praktikum - Tech Business Automation Im Ventur...
# 2389                             Customs Representative
# 1311                                              It Mm
# 3664              Rear - Warehouse Logistical Clearance
# 2026                      Finance M Media Communication
# 2371                Advisory - Excellence Restructuring
# 248                                 Bindability Otto De
# 3359                                          Executive
# 1719  Supply Network Planning Tz Max 20 Hours Week 1...
# 3394                                             Growth
# 4526                                                It-
# 2040                   W2 Ship Organization Social Work
# 3918                                 Sw Solutions Radar
# 3866                        Community Growth Engagement
# 4322                                              Ui Ux
# 325                          - Metering Devices Tax Box
# 3463                                          Executive
# 3957                                     Optical Berlin
# 2401                                     Bioprocess Usp
# 3018                     Chemical Laboratoryant Quality
# 929   Life Sciences Greater North Rhine-Westphalia L...
# 3402                                             Oracle
# 2502                                    Lagerist Ousprc
# 3654                     Apprentices Tax Clerks Studies
# 3300                                          Balance -
# 3259               We Are Looking You To Strengthen Our
# 2969              Recruiting - Human Resources Personal
# 2988                 Calibration Measurement Technology
# 4114                                                It-
# 3532                      Applicationsentwickler - Java
# 2454                                        Secretariat
# 3444                                         E-Commerce
# 554                                          Media Dach
# 2223                            It Architecture Defense
# 2307                                   Assortment Space
# 3339  Bachelor Thesis Further Testing Special Soleno...
# 3030  Director Turn Projects Pharmaceutical Filling ...
# 772                                                  It
# 1755                              Maintenance Stuttgart
# 3351                                   Fullstack Munich
# 3816                                Frontend - Platform
# 3791       Trainer Passenger Handling Plane Manufacture
# 302                     Business Informatics Neckarsulm
# 2628                                  Quality Assurance
# 2397                                     Ot- Healthcare
# 2512                                              Clerk
# 563          Phd Research Multi-Modal Perception Fusion
# 3725                                              Cobol
# 3020                                  Telecommunication
# 3602    Legal - Digital Legal Process Annotation Design
# 1874             Bachelor Science Rsw Taxes Examination
# 1109  Medical Science Liaison - Indication Infectiou...
# 2757                                     Studienberater
# 1223                        - Laboratory Liner Backings
# 2219       Training Merchants Office - Purchasing 01 08
# 1556                                                Crm
# 3931                                    Physiotherapeut
# 2594                      Food Chemist Declaration Test
# 2640                                               Call
# 3082             Business Informatics Campus Or Virtual
# 312   Regional - Pain Osteoporosis Nutritional Suppl...
# 2101                                          Analytics
# 581                              Scientist Biochemistry
# 3894                                   Southern Germany
# 2971                                   Pharmaproduktion
# 2970                                           Chemical
# 225   Digital Transformation Office - Radical Standa...
# 1772                                      Cybersecurity
# 4112                                           Founders
# 4395                                             Im It-
# 4227                                                Afc
# 859        Dual Studies Central Banking Central Banking
# 4072                                            It- It-
# 2063                                          - Invoice
# 3820       Air Safety Security Training Career Changers
# 2538                                  Quality Assurance
# 3699                                     Ceo Assistance
# 3568                                     Shopping Clerk
# 514                                                - Hr
# 2150                Legal Counsell - Symikusus Rightage
# 4464                                      Teamassistenz
# 2916                                          Hr People
# 2206             Large Language Models Automation Tools
# 4054                Scan Office Power Preparation Files
# 3514                                              - Tax
# 2409                               Backoffice Insurance
# 4520                                  Bank Organization
# 1667                                   Fi Co Functional
# 4424                                    Flight Dynamics
# 2185                                            Monteur
# 1686                                       Psychologist
# 1708  Ifrs 9 Impairment Calculation Risk Reporting D...
# 4296                                            Project
# 729                         Cyber Strategy Architecture
# 2260                    Assistant Analysis Food Samples
# 3230                     Psychologist Fee Or Part -Time
# 2723                             Tax Reporting Strategy
# 2720                           Customs Trade Compliance
# 4049                                     Ui Ux Designer
# 2395  W2 Ship Theories Social Work Social Transforma...
# 2164                             Information Technology
# 3138                                                 Qm
# 531                            Digital Forensic Analyst
# 2686                              Retail Nopping Stones

# %%
df[(df.job_category == "Other") & (df1.title.str.contains("security|cybersecurity|penetration", case=False))] = \
other_category[other_category.title.str.contains("security|cybersecurity|penetration")].replace("Other", "IT|Cybersecurity|Security Engineering")

# %%
df[(df.job_category == "Other") & (df1.title.str.contains("software", case=False))] = \
other_category[other_category.title.str.contains("software")].replace("Other", "IT|Software Development|Full-Stack Development")

# %%
df[(df.job_category == "Other") & (df1.title.str.contains("informatics", case=False))]= \
other_category[other_category.title.str.contains("informatics")].replace("Other", "IT|Data & AI|Data Analysis")

# %%
df[(df.job_category == "Other") & (df1.title.str.contains("cloud", case=False))] = \
other_category[other_category.title.str.contains("cloud")].replace("Other", "IT|DevOps & Cloud|Cloud Engineering")

# %%
df[(df.job_category == "Other") & (df1.title.str.contains("business analys", case=False))] = \
other_category[other_category.title.str.contains("business analys")].replace("Other", "IT|Data & AI|BI")

# %%
pd.set_option('display.max_rows', 1384)
df[df.job_category == "Other"]
# Out:
#                                                   title  \
# 66    Final Thesis Validation Routing Algorithm Betw...
# 70                                    Programming Tutor
# 74                                  Content Development
# 77                      Insurance Mathematician Acarrow
# 80                        Consultant Telecommunications
# 87                 Autering - Risk Modeling Reservation
# 99                                Afc Modelling Manager
# 102           Praktikum Founders Im Travel-Tech Startup
# 103                                 Climate Risk Intern
# 113   Master Thesis Development Car Code Precise See...
# 126   Physicists Development Optical Measurement Tec...
# 127                      Speaker Controlling Statistics
# 128   Intern End-To-End Funnel Intelligence Digitiza...
# 130         Field Insights Analytics Advanced Analytics
# 143                            Employee Commercial Area
# 157                             Economist Insurance Esg
# 163   Bachelor Thesis Final Thesis Predictive Analyt...
# 164                                  Laser Application
# 175                                         Geosciences
# 185                          Controlling - Digitization
# 189                  Practice Field Banking - Assurance
# 191                                        Afc Modeller
# 196   Dr Rer Nat Theoretical Physics Applied Mathema...
# 202              Consultant Analyst Digital Measurement
# 208                     Product Owner Digitale Services
# 209   University Concentration Psychological Methodo...
# 222                                   Produktmanager It
# 225   Intern Digital Transformation Office - Radical...
# 228                       Mandatory Area Final Assembly
# 234            Praktikant Digital Factory Campus Berlin
# 236   Total Vehicle Testing Operational Strength Oct...
# 238                              Speakers - Specialist
# 248      Product Bindability Product Management Otto De
# 261                               Customer Experience -
# 269                      Referent Innovation Technology
# 276                   Backend-Entwickler Embedded Linux
# 279                    Product Owner - Digital Products
# 286          Account Executive B2B Bei Modelyzr Münster
# 295                     Seller Part -Time 21 Hours Week
# 296                                         Ux Designer
# 297                     Or Intern Insurance Mathematics
# 298                                           It Expert
# 308   Assistant Institute Management - Bilingual Ger...
# 312   Regional Manager - Area Pain Osteoporosis Nutr...
# 322   Project Assistance Full -Time Part -Time Suitable
# 325          Product Manager - Metering Devices Tax Box
# 326   Pharmaceutical Advisors Pharmaceutical Officer...
# 348                         Internships Theses Students
# 350             Masterand Llm-Based Plc Programming Rag
# 355                         Or Thesis Field Text Mining
# 362                                        Quant Trader
# 388                        Iracing Wheelslip - 20H Week
# 396                                  Investment Analyst
# 397                 Consultant - Digital Transformation
# 407                                   Account Executive
# 418                Space Situational Awareness Engineer
# 440                              Sea Paid Media Manager
# 446                               Consultant Ibm Cognos
# 452                                    Sales Generalist
# 454                   Tm1 Planning Analytics Consultant
# 455                   Tm1 Planning Analytics Consultant
# 460                   Tm1 Planning Analytics Consultant
# 465                                          Thesis Sap
# 468                                   Account Executive
# 469          Laravel Developers - Home Office - Germany
# 477                    Sales Development Representative
# 478                    Scientist - Systems Pharmacology
# 480                                   Account Executive
# 481                                Laboratory Assistant
# 483                    Sales Development Representative
# 490     Publisher Sustainability Life Sciences Journals
# 507                Servicenow Platform Solution Analyst
# 508                                             Actuary
# 512                     Programmer Ecological Modelling
# 513         Phd Generative Models Closed-Loop Synthesis
# 514                                                - Hr
# 516   Quantitative Genetics Scientist Sugarbeet Cereals
# 517                               New Processing Pilot
# 522                      Intern Global Finance Treasury
# 530                              Phd 6G Technologies Iv
# 531                            Digital Forensic Analyst
# 532                              - Steel Tower Sourcing
# 3041                           Expedient 2 Years Ousprc
# 3047                        Storage Engineer San Plswus
# 3052  Payment Specialist Für Schemes Mastercard Visa...
# 3054                                Quality Partner Gmp
# 3056                              Ams Consultant Sap Mm
# 3058  Transport Manager - Dortmund Transportation Pr...
# 3061             Director Travel Industry Entertainment
# 3062             System Drives Pre-Sales Leader Germany
# 3066                                         Legal Dach
# 3068                                  It-Revisor Revpur
# 3069                             Testmanager Cobkpm Dmm
# 3070                            It System-Administrator
# 3073                                     Ehs Manager Am
# 3075  Product Manager Vr -Control - Special Tests Co...
# 3078                        Commercial Employee Billing
# 3080  Kitchen Help Full Or - Courtyard By Marriott M...
# 3084                         Scrum Scrums Master Plsdbs
# 3085                  Speaker Reporting Administration
# 3088                   Bachelor Master S Theses It Area
# 3095                               Bim- Cad-Koordinator
# 3098                                         Breafinery
# 3100                     Project Assistant Part -Time S
# 3101  Self-Responsible Caretaker Renovation Tasks Bo...
# 3103          Bachelor Master Thesis Sw Solutions Radar
# 3112                        Operations Planning Analyst
# ...
# 3931  Personality with PROFILU has a completed degre...        Other
# 3937  We are looking for these requirements:You have...        Other
# 3940  8+ years of experience in B2C e-commerce leade...        Other
# 3946  Successfully completed studies in the field of...        Other
# 3947  You are a trained tax specialist (m/f/d) and y...        Other
# 3954  Languages Required: fluent German and EnglishE...        Other
# 3957  University degree or equivalent qualification ...        Other
# 3962  Job DescriptionYou are an experienced structur...        Other
# 3964  Unzox your assets Your profile degree: digital...        Other
# 3968  Ideally have a background as a qualified Medic...        Other
# 3970  Technical knowledge of builder or developer to...        Other
# 3971  You have excellent knowledge and experience in...        Other
# 3972  You've worked in fast-paced environments befor...        Other
# 3974  Required qualificationsEducation & skillsDegre...        Other
# 3976  Professional experience in sales, ideally in t...        Other
# 3978  Qualifications:Your profile3+ years of relevan...        Other
# 3980  Completed degree in Business Administration, M...        Other
# 3983  RequirementsExperience & Track Record7+ years ...        Other
# 3985  Your profile:- completed studies (FH-Diplom/Ba...        Other
# 3986  Hands-on mindset: You proactively tackle chall...        Other
# 3993  Requirements5+ years of experience in clinic r...        Other
# 3996  Your profile and job mediation (% placement ra...        Other
# 3999  Qualification:- You bring completed commercial...        Other
# 4000  Creation of company private tax returns We exp...        Other
# 4007  Skills and experiences • Completed business st...        Other
# 4011  If we expect the right to preliminary knowledg...        Other
# 4012  At least in the third semester: You study grap...        Other
# 4014  WHAT YOU NEED TO KNOW (or TECHNICAL SKILLS)Exp...        Other
# 4027  Completed at least four semesters with great a...        Other
# 4029  • Enthusiasm for movement, therapy and sport •...        Other
# 4031  6+ years of experience as a software developer...        Other
# 4034  Proven experience in project management within...        Other
# 4037  You love: dealing with numbers of passionate -...        Other
# 4038  5+ years of hands-on CRM experience(email, pus...        Other
# 4040  5+ years of hands-on CRM experience(email, pus...        Other
# 4047  7-10 years of experience in product management...        Other
# 4049  Ideally a completed apprenticeship in a logist...        Other
# 4052  What we expect from you• Language Skills: Flue...        Other
# 4053  Student of industrial engineering or engineeri...        Other
# 4054  Your profile:- Completed training or study in ...        Other
# 4055  acquiring B2B clientsrecruitment agency player...        Other
# 4057  And the management of the quality controlledas...        Other
# 4062  You have completed a completed commercial or t...        Other
# 4063  Your profile (93.7%) Personal: Technical skill...        Other
# 4064  Completed vocational training as a dental tech...        Other
# 4065  Successfully completed training as a foreign l...        Other
# 4066  You have several years of experience in the (i...        Other
# 4069  12+ years’ experience working in Solutions Eng...        Other
# 4071  Professional experience in direct sales, ideal...        Other
# 4072  You have a degree in business or business info...        Other
# 4074  Several years of experience in the implementat...        Other
# 4079  Your qualification- completed vocational train...        Other
# 4080  The ideal candidate will have experience of mo...        Other
# 4081  Better to be active in the fresh air instead o...        Other
# 4085  You have successfully completed your studies i...        Other
# 4086  Your property endu appreciates a modern work e...        Other
# 4088  Very good knowledge of PHP 7 and OOP as well a...        Other
# 4089  - Completed training in the areas of offset pr...        Other
# 4090  As a senior developer (m/f/d), you are well ve...        Other
# 4096  You have (soon) Abitur you have a good underst...        Other
# 4098  is a student of computer science, business inf...        Other
# 4099  PROFILEBachelor’s degree, preferably a Master’...        Other
# 4109  - Successfully completed training as BTA, CTA,...        Other
# 4111  Enrolment at a university (Immatrikulationsbes...        Other
# 4112  Currently pursuing a Bachelor's or Master's de...        Other
# 4114  You can do this with:- Training or study with ...        Other
# 4118  Professional experiences from the hide, in the...        Other
# 4123  - Completed vocational training in the IT area...        Other
# 4124  Student in business, management, economics, IT...        Other
# 4125  They are above average sociable and strong in ...        Other
# 4126  Degree in Chemistry, Chemical Engineering, or ...        Other
# 4130  You should bring qualification? You should hav...        Other
# 4132  RequirementsWhat we expect:Hold a degree in Bu...        Other
# 4135  EducationPostgraduate degree in economics, eco...        Other
# 4137  Your profile: You have a bachelor, master or m...        Other
# 4138  • A completed degree in a relevant area (such ...        Other
# 4139  BasicExcellent verbal and written communicatio...        Other
# 4140  Have 3+ years of experience building software ...        Other
# 4141  Successfully completed degree in (economic) co...        Other
# 4143  Vibration Analysis skills, with other predicti...        Other
# 4145  Intermediate proficiency in MS Office Suite: O...        Other
# 4147  Knowledge and skills"Your Toolbox"Completed tr...        Other
# 4149  . Qualification of checklisting years of exper...        Other
# 4150  Successfully completed study of the specializa...        Other
# 4152  WHAT YOU BRING | THE PERSONThe ideal candidate...        Other
# 4153  A good average school leaving certificate, tec...        Other
# 4154  Strong portfolio showcasing experience(4+ year...        Other
# 4156  You go to people openly and friendly, like to ...        Other
# 4158  You bring this with- You have successfully com...        Other
# 4164  Professional & strategic years of experience i...        Other
# 4167  At least in the third semester: You study grap...        Other
# 4181  Bachelor or comparable conclusion with a focus...        Other
# 4186  ▸ Completed study of the specialization of che...        Other
# 4187  * University or FH degree of computer science ...        Other
# 4190  Your profile · degree in economics, economics,...        Other
# 4191  Please be aware that this internship must be a...        Other
# 4192  Please be aware that this internship must be a...        Other
# 4193  At least 8 years of experience in customer man...        Other
# 4198  Key Components of Our Tech StackWho you are6+ ...        Other
# 4200  Class B driving license (your own car is advan...        Other
# 4203  Your Profildu has successfully completed your ...        Other
# 4204  QualificationsWas you bring -up university ent...        Other
# 4207  Commercial training: You have completed a comm...        Other
# 4213  Completed studies in economics, design, innova...        Other
# 4216  Ideally, you hold Paramedical or Nurse degree ...        Other
# 4218  Interest in dentistry and joy in working in th...        Other
# 4219  At least one medium school-leaving team and co...        Other
# 4220  Experience working with accounting or finance ...        Other
# 4222  General or subject -bound university -mature e...        Other
# 4226  You, because you feel in the world of numbers ...        Other
# 4227  Initial experiences in testing are desirable, ...        Other
# 4234  You have completed vocational training and hav...        Other
# 4236  You have successfully completed a training/app...        Other
# 4237  Prosfessional experiencedepending on the train...        Other
# 4242  >Bachelor’s/Master’s Degree in Electrical Engi...        Other
# 4243  Requirements:3+ years’ experience in a UI/UX D...        Other
# 4247  BasicExcellent verbal and written communicatio...        Other
# 4255  Your profile • Completed training as biologica...        Other
# 4256  Training as an IT specialist System integratio...        Other
# 4261  Training as an IT specialist System integratio...        Other
# 4264  Completed studies in the field of economy, com...        Other
# 4270  Ideally completed further training as a data p...        Other
# 4273  Entry-level to 1 year of sales or professional...        Other
# 4274  At least 7 years of relevant experience with i...        Other
# 4276  You have completed a degree in business admini...        Other
# 4278  You are a well-rounded designer, who steps bac...        Other
# 4282  Completed studies in the field of architecture...        Other
# 4284  Completed studies in the field of computer sci...        Other
# 4286  We're seeking an individual with a solid found...        Other
# 4290  You are at a university or university of the a...        Other
# 4295  Job description: Strong practical relevance en...        Other
# 4296  Completed studies in the field of pharmacy, bi...        Other
# 4301  Experience: Proven affiliate/monetization expe...        Other
# 4303  Completed railway company training with at lea...        Other
# 4304  You bring requirements with a completed techni...        Other
# 4305  Completed studies in digital business, marketi...        Other
# 4306  leading and expertise related to the ServiceNo...        Other
# 4307  Please bring the qualification to bring: Train...        Other
# 4308  A passion for identifying and solving complex ...        Other
# 4311  You study in the field of business administrat...        Other
# 4313  You bring this with- You have successfully com...        Other
# 4314  5+ years of hands-on experience in a senior cu...        Other
# 4316  You bring 2-4 years of experience in graphic o...        Other
# 4317  About the roleUserlane is searching for an inn...        Other
# 4318  Bachelor or comparable conclusion with a focus...        Other
# 4321  At least in the third semester: You study grap...        Other
# 4322  At least junior experience in UI/UX Design and...        Other
# 4324  Requirements:3+ years’ experience in a UI/UX D...        Other
# 4327  • A commercial training or a degree in the fie...        Other
# 4328  Completed commercial training such as a busine...        Other
# 4332  - Successfully completed training as BTA, CTA,...        Other
# 4335  Skills & RequirementsYou have a completed degr...        Other
# 4336  • Completed training in the area of electronic...        Other
# 4337  Ideally Experience in telecommunications cable...        Other
# 4339  What you please bring to professional experien...        Other
# 4342  7+ years of experience in the B2B sales, of wh...        Other
# 4348  Previous retail industry experience, specifica...        Other
# 4352  You have a completed commercial or medical voc...        Other
# 4353  ‍Ients have several years of experience in the...        Other
# 4354  You can do this with:- Experience in online ma...        Other
# 4356  Ideally Experience in telecommunications cable...        Other
# 4361  You have successfully completed your training ...        Other
# 4364  Completed university studies in the field of e...        Other
# 4365  Educational study in the field of marketing, b...        Other
# 4368  Completed university studies in the field of e...        Other
# 4372  It is assumed: Completed university or bachelo...        Other
# 4375  You have a degree in business informatics, com...        Other
# 4376  Completed studies of medicine and further trai...        Other
# 4378  You have a successfully completed university d...        Other
# 4382  You have a degree in business informatics, com...        Other
# 4383  You have a successfully completed university d...        Other
# 4387  This is the case with the completed training a...        Other
# 4389  Experience:Writing Skills:Languages**Education...        Other
# 4391  • Several years (at least four years) Experien...        Other
# 4392  This position requires both technical expertis...        Other
# 4395  Your profilePosition requirementsA minimum of ...        Other
# 4396  Bachelor's degree in Supply Chain Management, ...        Other
# 4400  At least 7 years of relevant experience with i...        Other
# 4403  Qualification of profile competencies & qualif...        Other
# 4404  You are enrolled student (m/f/d) in the field ...        Other
# 4406  Bachelor's or Master's degree in Business, Fin...        Other
# 4412  5+ years of experience in operational Supply C...        Other
# 4413  WHO ARE WE LOOKING FOR?Our highest priority is...        Other
# 4418  BwL studies or a similar degree-theory-related...        Other
# 4424  Deep understanding of the German public sector...        Other
# 4426  You have completed your studies in computer sc...        Other
# 4427  At least 3 years of experience in backend deve...        Other
# 4428  Successfully completed study of the specializa...        Other
# 4429  Minimum 10 years of relevant work experience i...        Other
# 4430  Your profile benefit to very good knowledge in...        Other
# 4432  - Bachelor’s degree or a comparable education ...        Other
# 4433  Your profilu would like to do a varied and exc...        Other
# 4437  We are looking for someone who has;Experience ...        Other
# 4438  A proactive mindset with a willingness to lear...        Other
# 4439  You have a degree in one mint subject. You hav...        Other
# 4442  To be successful in this position, we would li...        Other
# 4443  You have5+ years of experienceas a UX Designer...        Other
# 4449  Your profile qualification knowledge of the kn...        Other
# 4450  Preferably pursuing a Bachelor's degree in Foo...        Other
# 4464  Recent graduate or currently enrolled in Compu...        Other
# 4467  Become an expert:Your profileYou are a graduat...        Other
# 4468  Bachelor's or Master's degree in Business, Fin...        Other
# 4469  Studies: You are currently enrolled: R student...        Other
# 4471  You are currently in a degree in Wiebwl, (medi...        Other
# 4473  Multi-year (at least four years) Experience in...        Other
# 4475  5+ years of experience selling SaaS/ enterpris...        Other
# 4491  Our customer requires negotiating German and E...        Other
# 4497  What you need to succeed:Proven experience as ...        Other
# 4498  Your profile benefit to very good knowledge in...        Other
# 4500  You have a completed training or a degree with...        Other
# 4508  This is a senior, experienced and highly netwo...        Other
# 4509                                                NaN        Other
# 4514  Your profile Your profile, well-founded knowle...        Other
# 4520  Your profile: successfully completed study of ...        Other
# 4521  Your profile: successfully completed study of ...        Other
# 4526  Do you love to find solutions for complex prob...        Other
# 4527  Completed commercial training or a comparable ...        Other
# 4531  Technical educationProven professional experie...        Other
# 4534  Successful conclusion of a technical course (b...        Other
# 4536  You have a degree in the field of architecture...        Other
# 4540  Training in the field of IT specialist for app...        Other
# 4543  Completed studies in the areas of HR, communic...        Other
# 4545  Practice from the user support: You have well-...        Other
# 4546  Technical basis with depth: You have several y...        Other
# 4547  Completed training as an IT system administrat...        Other

# %% [markdown]
# # after checking all the rows we can confidently say that there are no important data mostly irrelevent jobs and some special niche jobs

# %%
other_drop_indexes = df[df.job_category == "Other"].index
df = df.drop(other_drop_indexes)

# %%
df
# Out:
#                                                   title  \
# 0                                Business Analyst - Im
# 1     Procurement Specialist Data Science Artificial...
# 2     Dhbw Studies - Data Science Artificial Intelli...
# 3                   Data Science Area Python Databricks
# 4     Dual Studies Data Science Artificial Intelligence
# ...                                                 ...
# 4539       Operations Manager Customer Service C24 Bank
# 4541                                    Cloud Architekt
# 4542  It Service Engineer-Analyst Smart Meter Softwa...
# 4544                                      It Specialist
# 4548                             It Security Consultant
#
#                                            company  \
# 0                                   Markant Gruppe
# 1     Leadec Management Central Europe BV & Co. KG
# 2          Liebherr-International Deutschland GmbH
# 3                                          ARAG SE
# 4                                         Deloitte
# ...                                            ...
# 4539                                       CHECK24
# 4541                                           ZDF
# 4542                                  Schleupen SE
# 4544  FERCHAU – Connecting People and Technologies
# 4548  FERCHAU – Connecting People and Technologies
#
#                              location                    job_type  \
# 0                           Offenburg            Feste Anstellung
# 1                           Stuttgart            Feste Anstellung
# 2                            Biberach                         NaN
# 3                          Düsseldorf  Studentenjobs, Werkstudent
# 4     Düsseldorf, Mannheim, Stuttgart         Ausbildung, Studium
# ...                               ...                         ...
# 4539                Frankfurt am Main            Feste Anstellung
# 4541                            Mainz            Feste Anstellung
# 4542                        Ettlingen            Feste Anstellung
# 4544                      Norderstedt            Feste Anstellung
# 4548                           Bremen            Feste Anstellung
#
#                    employment_type  \
# 0     Homeoffice möglich, Vollzeit
# 1     Homeoffice möglich, Vollzeit
# 2                              NaN
# 3     Homeoffice möglich, Teilzeit
# 4                         Vollzeit
# ...                            ...
# 4539                      Vollzeit
# 4541            Teilzeit, Vollzeit
# 4542  Homeoffice möglich, Vollzeit
# 4544  Homeoffice möglich, Vollzeit
# 4548                      Vollzeit
#
#                                             description  \
# 0     There is a lot of know-how in our medium-sized...
# 1     With 14,500 employees worldwide and more than ...
# 2     Monari is a future-oriented and international ...
# 3     IONITY is a joint venture of the car manufactu...
# 4     ZS2Radätteilen GmbH is one of the leading Germ...
# ...                                                 ...
# 4539  C24 Bank GmbH is part of the Check24 Group. Un...
# 4541  The Planning and Realization business area (PU...
# 4542  We are an innovative medium -sized software co...
# 4544  Combining people and technologies, designing t...
# 4548  Do you know that security comes first in today...
#
#                                            requirements  \
# 0     Ongoing studies in the field of computer scien...
# 1     You bring many years of professional experienc...
# 2     Successfully completed degree in business info...
# 3     You have a successfully completed degree in th...
# 4     Completed scientific university studies in com...
# ...                                                 ...
# 4539  Completed studies (diploma [FH]/Bachelor) in t...
# 4541  You have a completed training as a bank clerk ...
# 4542  Completed vocational training as a specialist ...
# 4544  Completed university education at an applied u...
# 4548  You bring a good conclusion as a bachelor's ch...
#
#                                        job_category
# 0          Public Sector & Non-Profit|NGO & Charity
# 1           Business|Procurement|Strategic Sourcing
# 2                         IT|Data & AI|Data Science
# 3                         IT|Data & AI|Data Science
# 4                         IT|Data & AI|Data Science
# ...                                             ...
# 4539  IT|IT Management|Product & Project Management
# 4541            IT|DevOps & Cloud|Cloud Engineering
# 4542             Engineering|Electrical Engineering
# 4544              Customer Service|Client Relations
# 4548                  Legal|Compliance & Regulatory
#
# [3083 rows x 8 columns]

# %%
df.to_csv("job_postings_classified.csv")
